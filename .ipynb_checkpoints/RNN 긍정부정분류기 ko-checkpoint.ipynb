# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
import pandas as pd
import numpy as np

naver_data = pd.read_table('./data/ratings.txt')
print(naver_data)
# Out:
#               id                                           document  label
# 0        8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1        8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2        4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3        9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4       10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1
# ...          ...                                                ...    ...
# 199995   8963373                                     포켓 몬스터 짜가 ㅡㅡ;;      0
# 199996   3302770                                              쓰.레.기      0
# 199997   5458175                  완전 사이코영화. 마지막은 더욱더 이 영화의질을 떨어트린다.      0
# 199998   6908648                왜난 재미없었지 ㅠㅠ 라따뚜이 보고나서 스머프 봐서 그런가 ㅋㅋ      0
# 199999   8548411                                    포풍저그가나가신다영차영차영차      0
#
# [200000 rows x 3 columns]

# %%
# 정규표현식을 사용하여 단어가 아닌것을 삭제

naver_data['document'] = naver_data['document'].str.replace("[^\w]|br", " ")
print(naver_data)
# Out:
#               id                                           document  label
# 0        8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1        8132799  디자인을 배우는 학생으로  외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2        4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음   최고       1
# 3        9251303  와   연기가 진짜 개쩔구나   지루할거라고 생각했는데 몰입해서 봤다   그래 이런...      1
# 4       10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화       1
# ...          ...                                                ...    ...
# 199995   8963373                                     포켓 몬스터 짜가 ㅡㅡ        0
# 199996   3302770                                              쓰 레 기      0
# 199997   5458175                  완전 사이코영화  마지막은 더욱더 이 영화의질을 떨어트린다       0
# 199998   6908648                왜난 재미없었지 ㅠㅠ 라따뚜이 보고나서 스머프 봐서 그런가 ㅋㅋ      0
# 199999   8548411                                    포풍저그가나가신다영차영차영차      0
#
# [200000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

document_train, document_test, y_train, y_test = train_test_split(naver_data['document'], naver_data['label'], test_size = 0.25, shuffle=True, random_state=3)
document_train.shape, document_test.shape, y_train.shape, y_test.shape
# Out:
# ((150000,), (50000,), (150000,), (50000,))

# %%
from konlpy.tag import Okt

# 예시용 stopwords (불용어)
stopwords = ['을', '를', '이', '가', '으로', '에게']

# 토큰화 진행

X_train = []
for stc in document_train:
    token = []
    words = Okt().morphs(stc)
    print(words)
    for word in words:
        if word not in stopwords:
            token.append(word)
    X_train.append(token)

# X_test = []
# for stc in review_test:
#     token = []
#     words = Okt().morphs(stc)
#     for word in words:
#         if word not in stopwords:
#             token.append(word)
#     X_test.append(token)
# Out:
# ['케스팅', '은', '화려하나', '주인공', '연기', '가', '별로']
# ['공포영화', '가', '아니라', '블랙', '코', '메디', '였다면', '평점', '더', '줬을거다', '황당', '저', '질', '3', '류']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '참', '잼', '잇네여']
# ['톰크루즈', '리즈시절', '물론', '연기력', '은', '호프', '만이', '甲', '중', '의', '甲']
# ['옛날', '영화', '라', '그런지', '좀', '세련된', '맛', '은', '없네요', '하지만', '정말', '최고', '의', '영화', '중', '하나', '라는', '것', '은', '분명합니다']
# ['멋진', '경', '주', '장면', '만으로도', '이미', '충분히', '만족스럽다']
# ['평점', '이', '중간', '없이', '최고점', '과', '최저', '점', '이', '많은데엔', '다', '이유', '가', '있다', '알바', '와', '안', '알바', '의', '차이', '역대', '급', '핵', '노잼', '극장', '에서', '소리', '소문', '없이', '사라진', '이유', '가', '있다']
# ['선교사', '님', '부부', '의', '인내', '와', '헌신', '에', '큰', '감동', '을', '받았네요', '눈물', '찔끔', 'ㅠ']
# ['그냥', '구림', '특히', '이민기', '연기', '제발', '좀']
# ['포스터', '에', '낚', '이지마']
# ['아', '빵', '점주', '고', '싶다', 'ㅠㅠ']
# ['영화', 'ㅠ', '아이', '병', '을', '접', '하며', '초반', '에', '아빠', '가', '계단', '에서', '뒤', '로', '넘어지며', '경기', '를', '일으키며', '오열', '하던', '모습', 'ㅜㅜ', '넘', '슬펏다']
# ['소름', '돋는', '중', '전혀', '예상', '못', '했다는', '둥', '평점', '때문', '에', '기대했는데', '식스센스', '본', '사람', '이', '면', '누구', '나', '다', '알', '수', '있는', '결말', '과', '반', '전임', '햇빛', '을', '못', '보는', '피부병', '에', '걸린', '자식', '편두통', '이', '심한', '주인', '여자', '수많은', '문', '을', '잠그고', '다녀야', '되는', '미스터리', '이리', '많은', '떡밥', '의', '반전', '이', '겨우', '이', '거', '라니']
# ['김혜수', '킹왕짱']
# ['아니', '그래도', '그렇지', '평점', '이', '1', '점', '은', '너무', '하잖아', '그걸', '유지', '하기', '위해', '나도', '1', '점쥼', '_']
# ['마지막', '5분', '소름', '돋았음']
# ['말', '이', '안', '나오는군']
# ['굿']
# ['평점', '이', '너무', '낮게', '형성', '되어있어', '아쉽네요', '두', '주인공', '의', '대화', '가', '하트', '인', '아틀란티스', '영화', '를', '떠올리게', '되내요', '다른', '듯', '비슷한', '여운', '과', '삶', '을', '뒤', '돌아보고', '생각', '하게', '하는', '영화인', '것', '같네요', '최소한', '한번', '씹고', '뱉어', '버리는', '껌', '같은', '영화', '는', '아닙니다']
# ['고향이', '영월', '인데', '이번', '추석', 'ebs', '특집', '으로', '첨', '봤네요', '솔직히', '박중훈', '씨', '갠', '적', '으로', '별로', '여서', '안', '본', '영화', '인데', '다시', '생각', '하게', '됐습니다', '시간', '이', '지나면', '다시', '한번', '보고싶', '어질거', '같네요']
# ['밋밋한', '반전', '긴장감', '없는', '카메라', '영상', '들', '머', '지', '머', '지', '하면서', '봄']
# ['감독', '걍', '광고', '나', '만들면서', '손가락', '빨고있어']
# ['삶', '이란', '인생', '이라는', '이름', '의', '관', '속', '에서', '계속', '해서', '희망고문', '당하다', '묻히는', '걸', '로', '끝난다']
# ['응', '헉', '이제야', '이', '걸', '찾게', '되다니', '제목', '도', '모르고', '내용', '도', '몰라서', '이제야', '찾았다', 'ㅠ']
# ['연출', '과', '비쥬', '얼은', '아직도', '따라올', '게', '없다']
# ['제', '가', '어연', '1년', '전에', '블랙', '가스펠', '이라는', '양동', 'ㄴㅇ', '렘넝리', 'ㅏㅁ', '너', '이', 'ㄹ', '쓰레기', '영화', '비', '추천']
# ['비싼', '돈', '들여', '유럽', '유학', '가서', '영화', '공부', '해서', '만들면', '이', '정도', '로', '만드는구나']
# ['맥', '양', '역시', '언제', '봐도', '이쁘다']
# ['주인공', '이', '쓰레기', '인', '영화', '자신', '만', '아니면', '안된다는', '쓰레기', '마인드', '를', '갖고있음']
# ['수녀복', '걸친', '정선경', '이', '김민종', '이랑', '으']
# ['몇', '년', '만에', '다시', '찾아보게', '된', '영화', '아', '다시', '봐도', '정말', '잊을', '수', '없는', '명작', '이에요']
# ['2002년', '에', '나온', '흠집', '찾기', '힘든', '명작', '영화']
# ['내', '생애', '최악', '의', '공포영화', '공포영화', '가', '무서워야', '되는데', '웃김']
# ['만점', '을', '안줄수가', '없다', '헐리웃', '도', '감히', '흉내', '낼수', '없는', '리얼', '액션', '의', '결정', '판', '레전드', '오브', '레전드']
# ['괜찮다고', '생각', '함', '평점', '너무', '낮안거']
# ['아', '내', '가', '이영화', '를', '돈', '주고', '봤다니', 'ㅜㅜ', '천추', '의한이로다']
# ['ㅋㅋㅋ', '스파이크', '강시', '브리', '시브', '테니스', '테니스']
# ['대충', '줄거리', '는', '듣고', '봤는데도', '모르겠다', '달님', '은', '알까', 'ㅡ', 'ㅡ']
# ['무엇', '을', '상상', '하던', '그', '이상', '을', '보게', '될것이다', 'ㅋㅋ', '무슨', '색', '페인트', '썩어', '냄새', '맡아야', '이런', '생각', '을', '하게', '되지']
# ['다시', '봐도', '질리', '지', '않고', '감탄', '하게', '되는', '영화']
# ['장르', '를', '모르고', '봐서', '그런지', '뒷', '부분', '에', '놀랬다', 'ㅋㅋ', '최민식', '전도연', '연기', '에', '몰입도', '짱']
# ['사는', '얘기', '재미', '와', '함께', '여운', '까지', '오랜', '만', '에', '짱', '맘', '에', '든다']
# ['또', '하나', '의', '쓰레기']
# ['보는', '내내', '이건', '아니라는', '생각', '이', '들었다']
# ['괜찮을', '뻔', '했던', '영화', '하지만', '뭔가', '뻔하고', '새로운게', '없다']
# ['김수로', '김영민', '좋다']
# ['인터넷', '소설', '이', '원작', '인', '갘', 'ㅋㅠㅠ', '너', '네', '그러다', '대학', '졸업', '하면', '헤어져']
# ['팝핀현준', '을', '주인공', '으로', '하던가', 'ㅋㅋㅋ', '주인공', '보다', '더', '잘추는데', '라이벌', '자체', '가', '안되는구만', 'ㅋㅋㅋ']
# ['이런게', '남자', '의', '드라마', '다']
# ['FTIsland', '민환', '오빠', '가', '나왔어요', 'ㅎㅎ', '넘', '짱', 'ㅋㅋ']
# ['저기', '내', '가', '엑스트라', '로', '나온다']
# ['개', '명작', '이', '죠', '그때', '당시', '에', '한국', '에서', '이런', '액션', '이', '가능했다는거', '자체', '가', '놀라울', '따름', 'ㅋㅋ', '어렸을', '때', '는', '그냥', '재미', '로', '봤었는데']
# ['우리나라', '진짜', '저랬었냐']
# ['신촌', '김영', '다니지', '마세요', '김', '플', '고고']
# ['굳', '스폰지', '에서', '봤는데', '이런', '영화', '들', '많이', '나왔으면', '좋겠어요']
# ['난해하다는', '세간', '의', '평', '을', '듣고', '좀', '쫄았는데', '왜', '이', '게', '난해하다는', '건지', '당', '최', '이해', '가', '안', '간다', '떡밥', '도', '다', '회수', '하고', '비유', '도', '진짜', '적절하고', '이', '정도', '면', '주제', '진짜', '명확하게', '잘', '전달', '한', '것', '같은데', '말', '이', '필요없는', '명작', '인', '건', '확실하네요', '작화', '연출', '스토리', '지금', '봐도', '정말']
# ['진짜', '내용', '말', '도', '안된다', '괜히', '본듯']
# ['진짜', '내생', '에', '최악', '의', '영화', '초반', '에는', '김장', '감', '조성도', '되고', '볼', '만', '햇', '는데', '중반', '부', '부터', '탄식', '그', '중', '에', '정말', '어이없던건', '마지막', '에', '살인마', '죽', '을', '때', '하', '웃엇음', '영화관', '에서', '안', '본게', '다행', '이지만', '무료', '로', '봣', '더라도', '시간', '이', '너무', '아깝고', '기분', '만', '더러', '웟음']
# ['모처럼', '영화', '같은', '영화', '를', '본', '듯', '하다', '영화', '같은', '영화', '가', '아닌', '현실', '같은', '영화', '굿']
# ['일본', '영화', '라고', '평점', '낮게', '주는건', '뭐', '냐', '유치하게', '스토리', '잘', '짜여있고', '감동', '도', '있더만']
# ['린치', '영화', '를', '다른', '영화', '처럼', '이', '성적', '으로', '이해', '하려고', '하니까', '재미', '가', '반감', '되고', '실망하는거지', '그렇게', '감상', '하는', '것', '도', '관객', '의', '자유', '겠지만', '이', '영화', '는', '분석', '하려고', '하면', '안되는건데']
# ['흔한', '영화', '가', '아니라', '이', '영화로', '부터', '영향', '받은', '영화', '들', '이', '흔해졌지', '개인', '적', '으로는', '8월', '의', '크리스마스', '첨밀밀', '러브레터', '와', '더불어', '동양', '멜로', '의', '마스터피스', '전설', '이라고', '할', '수', '있지']
# ['황인식', '이', '나오는', '순간', '부터', '액션', '이', '바뀌는', '것', '이', '느껴진다', '후반', '부', '긴', '액션', '장면', '은', '감탄', '이', '나온다', '관절', '기', '가', '나오는', '무협', '영화', '라니']
# ['난', '제일', '이해', '가', '안되는게', '달', '에', '잇던', '병사', '들', '이랑', '우주선', '이', '어떻게', '해서', '시카고', '로', '오게됫는', '지', '그', '과정', '이', '하나', '도', '없음', '그냥', '전기', '지지', '직', '하더니', '디셉티콘', '들', '몇', '마리', '튀어나오고', '우주선', '은', '그냥', '갑자기', '시카고', '상공', '에', '떠', '잇음', '중간', '과정', '없이', 'ㅋㅋ', '그리고', '여', '주인공', '이', '쓰', '레깅']
# ['언뜻', '보면', '단순한', '영화', '같지만', '여운', '이', '이상하게', '길다']
# ['이제', '는', '나오지', '않을', '스', '플래터', '무비', '최고', '의', '걸작']
# ['절', '대보면', '후회', '할', '영화', '여기', '알바', '들', '진짜', '많은듯']
# ['꿀잼', '이지만', '이자스민', '극혐']
# ['키', '아누', '리브', '스', 'ㅜㅜ', '너무', '멋있네요', 'ㅜㅜ', '재밌어여', '볼', '만해', '여']
# ['파주', '주의', '기묘한', '모험', '이다']
# ['재밌었는데', '이제', '슬슬', '짜증나려', '고해', '요', '스토리', '도', '적당히', '풀었다', '꼬았다', '해야지', '이건', '마냥', '꼬기', '에만', '바쁘네요', '적당히', '하시고', '종영', '하세요', '막무가내', '로', '막장', '인', '것', '도', '지겹고', '보면서', '스트레스', '받는', '드라마', '저', '는', '그만', '볼래요']
# ['몽환', '적', '인', '분위기', '와', '영', '상미', '빼고는', '별로', '3시간', '러닝', '타임', '에', '스토리', '전개도', '지루하고', '바다', '에', '대한', '동경', '보다는', '이상한', '잠수', '대회', '얘기', '나', '하고', '무엇', '보다', '조', '안나', '에', '대한', '무책임한', '태도', '에', '보는', '내내', '화가', '났음']
# ['시리즈', '다', '봤어요', '이', '전', '시리즈', '보다', '훨씬', '재밌구요']
# ['여기', '에', '나온', '주', '조연', '단역', '지금', '현재', '다', '명성', '있는', '배우다']
# ['조', '낸', '개', '어설프다', '춤', '사위', '가', '그게', '머냐']
# ['영화', '의', '의미', '를', '파악', '할수', '없었다', '장면', '연결', '이', '부실하게', '느껴졌다']
# ['전편', '보다', '잼있다', '전편', '보고', '실망해서', '인서전트', '안', '보는건', '손해', '다']
# ['몬태나', '의', '아름다', '움']
# ['역시', '스티브잡스', '씬들', '의', '텍스쳐', '하나', '하나', '가', '소름끼치게', '디테', '일하다', '나루토', '나', '원피스', '같은', '2', 'D', '그래픽', '이랑은', '아예', '차원', '이', '다르고', '너무', '만족스러웠던', '영화']
# ['대사', '며', '연출', '이며', '너무', '너무', '허', '접함', 'ㅠ', '영화', '의', '주제', '조차', '제대로', '전달', '안됨', '노력', '많이하세요']
# ['재밌어']
# ['보는내내', '행복했습니다', '잔잔하지만', '따뜻한', '영화', '네', '요']
# ['중학교', '때', '보았는데', '내', '인생', '제일', '재미', '없었던', '영화', '_']
# ['재연배우', '보는듯', '한', '연기', '와', '노리개', 'B', '급판', '소재', '포르노그래피', '를', '보여주고자', '한', '것', '도', '아니고', '사회', '고발', '영화', '도', '아니고', '뭔', '지', '모를', '필름', '아깝지', '않나', '감독', '은', '요즘', '영화', '안보', '나', '아싸', '리', '되놓고', 'B', '급', '으로', '가던지', '뭐', '야', '이', '거', '어정쩡한', '영화', '는']
# ['부모님', '과의', '시', '간편', '감동', '이었', '고제', '마음', '에', '짠한', '무언가', '가', '와', '닿았습니다', '친근하고', '사랑', '이', '넘치는', '데프콘', '부모님', '도', '따뜻하고', '무조건', '적', '인', '사랑', '을', '주시', '는', '김태원', '님', '어머님', '도', '그렇지만', '울컥', '하며', '눈물', '이', '났던', '순간', '은', '무뚝뚝함에', '가려진', '이성재', '님', '아버지', '의', '속', '내', '를', '들을', '때', '였어요', '최', '곱니다']
# ['연기', '잘', '해요', '대', '상감', '이유리', 'ㅋ']
# ['시청률', '이', '왜', '낮은지', '생각', '해보렴', 'ㅎ']
# ['픽션', '이지만', '재미', '뚬', 'ㅎㅎ']
# ['볼프강', '피터', '젠', '지', '린다']
# ['중요한것은', '고인', '들', '의', '명복', '을', '빕니다']
# ['공포영화', '의', '수작', '공포', '스러우면서도', '그', '보다', '환타지', '적', '인', '성격', '이', '강했다', '독특한', '배경음악', '과', '함께', '특유', '의', '분위기', '가', '특징', '여', '주인공', '당시', '어린시절', '미모', '가', '상당하고', '침팬지', '의', '활약', '까지', '여운', '이', '많이', '남는', '영화', '다']
# ['와', '이', '거', '센세이션', '이다', '반전', '돋음']
# ['아버지', '의', '아들', '을', '찾기', '위', '한', '박력']
# ['죽음', '과', '많은', '것', '을', '묵상', '케', '하는', '아주', '좋은', '영화', '눈물', '이', '난다']
# ['진지한', '무술', '액션영화', '일', '줄', '알', '고', '봤다가', '허탈하게', '웃으며', '끝났다', '뱀독', '다루는', '사람', '웃긴', '듯', '우물', '액션', '장면', '이', '기억', '에', '남음']
# ['평점', '조', '작', '질', '이', '좀', '심한듯']
# ['너무', '잘', '못', '된', '평점', '일듯']
# ['재미', '없을', '줄', '알면서', '봤지만', '역시', '내', '예상', '이', '맞았어']
# ['평점', '보고', '아이', '들', '과', '보러', '갔다가', '자고', '온', '영화', 'ㅜㅜ', '정말', '보고', '총', '평', '쓴', '건지']
# ['기대', '안해', '서', '인가', '열대야', '라서', '그', '런가', '재미있게', '잘', '봤네요']
# ['내용', '떠나서', '제작', '진', '해명', '이나', '대응', '조차도', '수준', '낮던데', '뭐']
# ['인간', '적', '인', '삶', '이란', '무엇', '인가', '에', '대한', '진지한', '의문', '을', '던져', '준다']
# ['이건', '뭐', '하']
# ['최고', '의', '영화', '사랑', '의', '가치', '를', '알려', '준']
# ['솔직히', '요', '몇', '년새', '에', '무서운', '영화', '다', '웠', '던건', '이영화', '뿐', '인거', '같네요', '요즘', '한국', '공포영화', '퀄리티왜', '이런', '가요', '재미', '도', '없고', '내용', '은', '산', '넘어', '산이', '고']
# ['형편', '없음', '스토리', '짜증', '렉서스', '사생활', '영화', '보단', '렉서스', '광고', '를', '위해', '출연', '한', '배우', '들']
# ['7', '점', '대', '는', '솔직히', '아니지', '중국', '영화', '다시', '보게', '만든것만으로도', '고', '득점', '가능']
# ['2011년', '개인', '적', '으로', '최고', '의', '걸작', '진실', '과', '가족', '두', '명제', '를', '갖고', '마법', '을', '빚', '어', '낸다', '두', '부부', '가', '마주', '앉은', '마지막', '복도씬', '마저', '예술', '극찬', '을', '바친다']
# ['케이티', '와', '크리스', '티', '자매', '가', '어릴', '적', '에', '겪었던', '미스터리', '한', '경험', '은근', '한', '맛', '이', '별로', '없이', '대낮', '에', '넘', '대놓고', '그런', '현상', '이', '전작', '에', '비해', '몰입도', '도', '좀', '아쉽다']
# ['서론', '결론', '의', '영화', '중간', '과정', '이', '모두', '생략', '된것', '같다', '한국인', '들', '이', '어떻게', '흑인', '의', '고통', '과', '아픔', '그리고', '구원', '을', '갈망', '하는', '그', '기쁨', '을', '어느', '새', '에', '이해', '하고', '노래', '로', '표현', '했는지에', '대한', '것', '이', '안', '나온다', '그저', '프리허그', '한번', '으로', '그', '들', '을', '이해', '한', '것', '일까']
# ['삶은', '순간', '의', '연속', '이다']
# ['충격', '그', '자체']
# ['호기심', '왕성', '한', '남중생', '정도', '면', '흥미롭게', '볼수', '있을지도']
# ['해적', '엄마', '가슴', '이', '좀']
# ['어디', '다가', '혹성탈출', '을', '갖다', '붙임', '진짜', '보면', '후회', '함', '완전', '돈', '아깝고', '환불', '받고싶다', '이건', '공포', '도', '아니고', '액션', '도', '아니고', '뭔', '영환', '지', '혹성탈출', '내', '사랑', '인데', '이름', '막막', '쓰지', '마', '요']
# ['소재', '는', '흥미롭지만', '판이', '작다']
# ['시간', '이', '아깝다', '재미없다']
# ['2012', 'ALL', 'IN', 'V', '4', 'HUSTLE', 'DOO', '최강', '두산베어스']
# ['이렇게', '아름다운', '영화', '가', '우리나라', '에서도', '많이', '만들어졌으면', '강', '추합니다']
# ['영화', '보는내내', '나를', '보는', '것', '같아', '소름끼쳤다', 'ㄷㄷ', '미셸', '공', '드리', '식', '으로', '남자', '에', '대해', '완전히', '파헤친', '영화', '강력', '추천', '함', 'ㅎㅎㅎ', '꼭', '보시길', '특히', '짝사랑', '한', '상대', '한테', '거절', '당', '한', '남성', '에게', '추천', '함']
# ['스토리', '보다', '아름답고', '순수함을', '찬란히', '표현', '한', '영화', '가', '참', '특별하다싶네요', 'ㅎㅎ', '이름', '이나', '죽음', '같은', '소재', '를', '볼때', '영원', '이란', '것', '을', '사랑', '과', '결부', '시켜놓은', '좋은', '작품', '같아요', 'ㅎㅎ']
# ['정말', '재밌었어요', '연기', '가', '굉장']
# ['올', 'ㅋ', '스타', '뎀', '아저씨', '는', '너무', '액션', '같은것보단', '이런', '스릴러물', '이', '더', '어울리다고', '해야되', '나']
# ['너무', '뻔하고', '시시했지만', '볼', '만', '했다', '온', '가족', '이', '볼', '수', '있는', '공포영화']
# ['다시', '보고', '싶네요', 'ㅠ', '이따금', '씩', '생각나는', '영화', '임']
# ['뻔한', '연출']
# ['난', '토마스', '가', '싫어']
# ['아', 'ㅠㅠ', '윤', '동하', '를', '보내야되', '다니', '너무', '슬프네요', 'ㅠㅠ', '저런', '완벽', '한', '남자', '는', '이', '세상', '어디', '에', '가야있나요', 'ㅜㅜ', '둘', '이', '이렇게', '케미', '가', '잘', '맞을줄은', '몰랐는데', '보는내내', '너무', '행복했어요', '반', '땡', '자', '알바', '윤둘', '정말', '잊지못', '할꺼', '같고', '흑', '흑', '드라마', '끝나지마', '잉', 'ㅠㅠㅠ', '정말', '재밌는', '드라마', '엿', '어요', 'ㅠㅠㅠㅠ', '최고']
# ['그', '남자', '의', '삶', '예술', '적', '영감', '헨델', '의', '음악', '까지', '굿']
# ['정말', '재미있다', '이연걸', '전성기', '시절', '모습', '과', '구숙정', '의', '미모', '몇번', '을', '다시', '봐도', '재미있는']
# ['상영', '관', '을', '많이', '확보', '해야죠', '정말', '관심', '둔', '영화', '였는데', '별로', '없네요', '진짜', '보고싶은데']
# ['2', '편', '은', '만들지', '않았어야']
# ['최고', '클로저', '와', '함께', '자랐다']
# ['나무', '기대', '를', '했는지', '그', '저', '그런', '로맨스']
# ['개', '잼', '하지만', '걍', '재밌기만', '한', '영화']
# ['후반', '갈수록', '지겨', '움']
# ['이', '거', '만화영화', '시리즈', '도', '참', '재밌게', '봤었지']
# ['오프닝', '과', '엔딩', '크레딧', '에', '재기', '가', '넘친다', '절대', '늦지도', '먼저', '일어서서도', '안되는', '영화', '다']
# ['스무살', '까지만', '사세요', '스무살', '까지만', '살고싶으면', '저', '는', '로', '즈', '드', '윗', '뷰', '케이', '터', '나이', '까지', '살래요']
# ['good', '말', '이', '필요없다']
# ['훈훈하고', '즐겁고', '벅찼다', '오버', '하지', '않아서', '더', '멋있게', '느껴진', '영화', '뭐라', '말로', '표현', '할', '수가', '없네']
# ['대박', '쩜']
# ['초반', '엔', '잼있었는데', '후반', '부로', '갈수록', '러브스토리', '에', '치중', '하다', '보', '니까', '많이', '루즈', '해젔', '던것', '같습니다']
# ['진짜', '재미있는', '드라마', '다시', '봐야지']
# ['최고', '명작', '중', '하나']
# ['타임머신', '드라마', '한편', '한편', '볼때', '마다', '느끼는거지만', '몰입', '감', '좋아서', '시간', '쭉쭉', '잘', '감']
# ['이런', '주제', '들', '도', '얼마', '든지', '재밌게', '만들수', '있지']
# ['아오', '씨밫', 'ㄱ', '이', '게', '영화', '임']
# ['송강호', '의', '위대함', '대단하다']
# ['이요원', 'ㅎㅎ', '이', '걸', '연기', '라고', 'ㅎㅎ']
# ['갑자기', '짐', '이', '싸고', '싶네']
# ['동화', '같은', '이야기', '매혹', '당하는', '느낌이였다']
# ['유쾌하게', '봤다', '의외로', '평점', '이', '낮은게', '이상하다', '그래서', '9', '점', '준다']
# ['아라', '때문', '에', '4', '점', '이라도', '줌', '고아라', '는', '진짜', '응사', '찍기전까지', '작품', '운', '이', '드럽게', '없었구나']
# ['다시', '봐도', '재밋', '고', '여러', '번', '봐도', '식상하지', '않은', '영화', 'ㅋ', '억지', '스럽지', '않고', '뭔가', '꾸미지', '않은', '자연스러', '움', '암튼', '이', '영화', '보고나서', '유아인', '나온', '영화', '는', '다', '찾아서', '보게', '됨', 'ㅋ', '생각', '없이', '편하게', '보기', '좋은', '영화', '다시', '봐야지', 'ㅋ']
# ['별루']
# ['저', '도', '재밌게', '봤어요', '평점', '믿을게', '못', '되는거', '같아요']
# ['미야자키', '하야오', '작품', '중', '쓰레기', '작품']
# ['알바', '에', '속지', '마라', '조', '낸', '쓰레기', '다', '보다가', '나갈려', '햇', '던건', '태어나서', '처음', '이다']
# ['전', '이', '거', '매일', '봐요', '저', '이', '거', '팬', '이에요']
# ['고독', '한', '영웅', '의', '모습', '이라', '할까']
# ['어쩐지', '화장실', '유머', '느낌']
# ['부', '반장', '같은', '영화']
# ['아', '진짜', '재미', '도', '없구', '이렇게', '쓰레기', '가', '튼', '영화', '는', '또', '오랜', '만이', '네', 'ㅡㅡ']
# ['평점', '이', '왜', '이리', '낮아', '재밌구먼']
# ['존나', '어색해', 'ㅡㅡ', '쓰레기']
# ['작가', '와', '연출가', '가', '듀엣', '으로', '멍청한', '탓', '에', '스트레스', '유발', '하는', '한심한', '드라마', '법률', '에', '관', '한', '사회', '일', '반', '상식', '이', '초등', '수준', '도', '않', '되는', '제', '작', '진', '은', '전파', '낭비', '의', '주', '범입', '니', '다']
# ['완전', '재', '미었어요']
# ['좀', '어려운', '감', '이', '있었지만', '관록', '있는', '배우', '들', '의', '섬세한', '심리', '묘사', '에', '감탄', '했고', '한', '편의', '연극', '을', '본', '것', '같은', '기분', '이었다']
# ['good', '데스', '네', '데스', '네', '데스', '네']
# ['서기', '는', '말', '라서', '안되', '보이', '고', '덕화', '씨', '는', '이제', '늙었구나', '하는', '생각', '이', '가볍게', '보긴', '좋아여']
# ['흔해', '빠진', '소재', '를', '대충', '찍어', '놓고', '독립', '영화', '니까', '감안', '하고', '보라', '는', '듯', '영화', '라고', '하는데', 'gif', '애니메이션', '보다', '스토리', '가', '더', '없음', '독립', '영화', '에서', '기대하는', '참신함', '따위', '는', '개', '나', '줘', '버린', '영화']
# ['1', '보다', '더', '재밌고', '3', '보다', '더', '완성', '도', '있다']
# ['완전', '쓰레기', '0', '점', '은', '없나']
# ['계단', '에서', '대사', '읊는', '장면', '이', '무척', '좋아서', '계속', '되새기게', '됨']
# ['30', '번', '넘게', '본듯', '배우', '들', '이', '연기', '나무', '잘', '함', '특히', '김남길', '진짜', '사랑', '하는듯', '이영훈', '씨', '도', '더', '뜨', '기를', 'ㅜㅜㅜ', '연', '기', '실력', '아까워']
# ['되게', '독특하고', '영상', '도', '예쁘고', '효과', '도', '소소하게', '예쁘고', '이야기', '도', '재밌고', '난', '진짜', '다', '좋았는데', 'ㅎㅎ']
# ['커스틴던스트', '를', '좋아하는데', '이영화', '에서', '매력', '퐁퐁']
# ['케릭', '터', '는', '유명해서', '기억', '에', '남지', '만', '내용', '은', '글쎄', '나', '와는', '안', '맞는', '소재', '와', '스토리']
# ['유사라', '연기', '는', '콧구멍', '조차', '어색하지만', '내용', '엄청', '파격', '적', '이고', '살색', '의', '향연', '이다']
# ['진짜', '재미', '강추', '안', '봤으면말을마', '삼']
# ['손발', '이', '오그라드는', '대사', '로', '넘쳐나는', '일종', '의', '현실', '도피', '성', '판타지', '약', '으로', '치면', '극약']
# ['굿']
# ['무척', '이나', '감동', '적이네요', '뭐', '웃', '을', '장면', '도', '드물지', '않고요']
# ['이보', '다', '더', '감동', '적', '일수', '없다']
# ['난', '너무', '정신', '없고', '재미없었음']
# ['왠지', '보고', '있으면', '따뜻함도', '먹게', '되는', '일본', '3', '대', '먹방', '영화', '중', '에', '하나', '카', '모', '메', '식당', '호노', '카아', '보이', '그리고', '남극', '의', '쉐프']
# ['130분', '이', '훌쩍', '지나갔네요']
# ['김재중', '은', '진리']
# ['ER', '보다', '리얼리티', '는', '훨', '낫네요']
# ['건물', '만', '짓는', '사람', '이', '아니라', '사람', '이', '사는', '공간', '을', '창', '출하', '는', '사람', '눈물', '이', '핑', '돌았습니다']
# ['그냥', '일본', '영화']
# ['새로운', '시도', '놀라', '움', '의', '대작']
# ['확실히', '일본애니', '평점', '은', '덕후', '들', '때문', '에', '믿을게', '못', '됨']
# ['재밌', '삼', '배우', '들', '신선하고', '맘', '에', '듦', '스토리', '가', '예고편', '에', '비해', '전개', '가', '질질', '거림']
# ['안타깝', '기도', '하고', '눈물나는', '드라마', '같은', '얘기', '좋앗습니다']
# ['최고', '였어요', '정말', '잊지못', '할거', '같아요']
# ['세상', '의', '모든', '일이', '그렇겠지만', '야구', '이기전', '에', '인생', '이구나']
# ['재밋다', 'ㅋㅋㅋ', '깜놀', '한', '부분', '도', '있었구']
# ['나', '고등학생', '인데', '이', '거', '봤다', 'OTL', '8', '살이', '하', '어린이', '꼭', '보세요', '그', '수준', '임']
# ['6', '25', '거제도', '포로수용소', '에', '왠', 'ak', '자동소총', '고증', '부터', '다시', '해라', '손발', '이', '오', '그라드', '네']
# ['한국', '형', '괴수영화', '의', '수작']
# ['도대체', '이런', '걸', '돈', '주고', '보라', '는', '건가', '양심', '없는것', '들']
# ['지금', '까지', '본', '공포영화', '100', '편', '중', '에', '거의', '99등', '100등', '에', '가까운', '이', '영화', '평점', '을', '보고', '알바', '라는', '게', '정말', '있구나', '확신', '하게', '됨']
# ['영화', '해석', '을', '보니', '내용', '은', '대충', '알겠는데', '연출', '이', '너무', '가볍고', '부실함', '아들', '놈', '병맛', '같은', '모습', '에', '중간', '에', '집중', '력', '을', '잃어버렸다']
# ['다수', '와', '소수', '의', '한바탕', '어울림', '우리', '도', '이러면', '살맛', '날텐데']
# ['평점', '이', '이렇게', '까지', '낮', '을', '필요', '까진', '없을것', '같은데', '영상', '도', '너무', '이쁘고', '온주완', '도', '귀엽고']
# ['펑점', '이', '이렇게', '낮다니']
# ['이', '게', '대체', '뭐', '냐', '보다가', '중지', '시간', '아깝다', '스으으읍얼']
# ['효', '주가', '좋아서', '계속', '보게', '되었지만', '효', '주가', '아직', '어려서', '밋밋하고', '푸', '풋함']
# ['대한민국', '최고', '의', '드라마']
# ['존', '나', '재밌네', '최고', '의', '영화', '다', '왠만한', '9', '점', '대', '이상', '보다', '더', '재밌는', '영화', '였다', '꼭', '보시길', 'ㅎ']
# ['지루했던', '하지만', '실화', '라는', '거', '에', '재미', '1', '점', '나머진', '소', '소']
# ['잘봤듭니', '다', '잘봤듭니', '다']
# ['이', '영화', '를', '극장', '에서', '돈', '주', '고본', '충격', '에서', '헤어', '나오지', '못', '하고있다']
# ['까', '락스', '나', '는', '이', '감독', '이', '지독히도', '싫다']
# ['평점', '이', '너무', '낮다', '개인', '적', '으론', '소름끼치게', '봤었는데']
# ['이성재', '가', '다시', '보이', '네', '와이프', '랑', '애', '들', '보기', '부끄럽지', '않을까', '우', '째', '저런', '영화', '를', '찍었을까', '유부', '남', '이']
# ['하하', '화려한', '출연', '진의', '눈요기', '서양', '의', '유퀘', '한', '똥', '이', '로다']
# ['이', '거', '왜', '개봉', '하는거지']
# ['꼴', '페미', '들', '이', '좋아할', '영화']
# ['아주', '괜찮네요', '볼', '만', '합니다']
# ['역시', '사람', '마다', '취향', '이', '다르군']
# ['보는내내', '즐거움', '으로', '봤지만', '마음', '한구석', '엔', '계속', '찡한', '맘', '을', '감출수가', '없네요', '감독', '과', '배우', '들', '이', '원하는게', '이런것', '아닐까', '요', '다시금', '봤지만', '정말', '좋은', '영화', '입니다', '배우진', '도', '정말', '최고', '조합', '이구', '요', '웃으면서도', '눈물', '이', '나네요', '정말', '좋은', '영화', '입니다']
# ['재미있음']
# ['평점', '이렇게', '낮', '을', '영화', '아님', '꼭', '한번', '보시', '고', '평가', '해보세요', '정말', '뜻', '깊고', '재밌음', '연기', '도', '훌륭함']
# ['2년', '전에', '봤던', '영화', '인데', '도', '불구', '하고', '아직도', '여운', '이', '많이', '남아', '있는', '영화', '그', '어떤', '공포영화', '를', '보면서', '느낀', '공포', '보다', '심리', '적', '공포', '가', '컸고', '하얀', '실크', '이', '너', '에', '피', '범벅', '이', '된', '채', '로', '욕실', '에서', '나오던', '그', '모습', '은', '아직도', '기억', '에', '남는다', '탄탄한', '스토리', '에', '소름끼쳤던', '연기', '완벽했다']
# ['죄다', '성괴', '들이네']
# ['하지원', '은', '이쁘다']
# ['초등학생', '1', '4', '학년', '조카', '들', '이랑', '갔는데', '집중', '하고', '잘', '보더라구요', '재밌었어요']
# ['이', '거', '보는섀끼', '존나', '후회', '함', 'ㅋㅋㅋㅋ']
# ['재미없어']
# ['예전', '의', '영화', '찾아서', '보는', '1', '人', '의', '한', '사람', '으로', '개인', '적', '이', '영화', '시작', '20분', '에', '포기']
# ['이영화', '너무나도', '보고싶은데', '예스', '파일', '이나', '이런', '유료', '영화', '사이트', '같은데', '아무리', 'OO', '봐도', '이', '영화', '는', '찾아볼', '수가', '없네요', 'ㅠㅠ']
# ['스토리', '좋고', '노래', '좋고', '그림', '예쁘고', '다', '좋은데', '그', '등', '날리는', '장면', '너무', '예쁘긴', '한데', '환경오염', '아닌가']
# ['느리고', '스릴', '없고', '지루하다']
# ['이건', '정말', '재미있다', '주성치', '천재', '아닌가', '서유기', '를', '이런', '식', '으로도', '풀어', '낼수', '있구나', '2', '편', '빨리', '나와라']
# ['삶', '에', '있어', '감사함을', '느끼고', '등장인물', '의', '마음', '을', '다', '느낄', '수', '있었던', '영화', '윤리', '적', '인', '문제', '로', '초반', '부분', '은', '의문', '점', '을', '풀었으나', '결국', '은', '풀리는', '깊은', '감동', '과', '여운', '을', '준', '영화', '보는', '내내', '눈물', '흘렸지만', '마음', '이', '따뜻해졌다']
# ['tv', '전', '기세', '가', '아깝다']
# ['이', '스토리', '어렸을', '때', '들어', '본적', '있는것', '같은데']
# ['의외로', '재밌어요', 'ㅋ']
# ['영화', '첫', '부분', '에', '많은', '등장인물', '들', '을', '소개', '해서', '그', '런가', '혼란', '스러웠다', '초반', '엔', '지루해서', '꺼', '버리고', '싶은', '충', '동이', '들었지만', '중반', '부터는', '그럭저럭', '무난', '한', '편']
# ['오늘', '새벽', '에', '우연히', '봤습니다', '억울한', '죽음', '들', '잊지', '않았으면', '좋겟네요']
# ['XX', '같은', '영화', '다']
# ['이영화', '가왜', '이렇게', '호불호', '가', '갈리는지', '모르겠다', '영화', '보는내내', '내', '가루', '카스', '배역', '에', '완전히', '몰입', '되있었다', '이만', '틈', '가족', '애', '를', '느낄수있는', '영화', '가', '과연', '얼마', '나더있는지', '궁금하네', '그리고', '루카스', '배역', '맡은', '배우', '분', '베', '댓', '말', '대로', '연', '기', '천재', '입', '니까']
# ['이', '시대', '에', '사람', '의', '마음', '을', '한편', '의', '그림', '으로', '표현', '하는게', '정말', '아름다웠고', '대단했다']
# ['내용', '이', '천녀유혼', '인', '줄', '귀신', '과', '사랑', '에', '빠진', '퇴마사', '배경', '이', '중화권', '이', '아닌', '유럽', '어딘가', '인', '듯']
# []
# ['감독', '이', '영화', '찍', '을', '기회', '를', '얻었으면', '잘', '만들어야지']
# ['노노노노', '나나', '나나', '나']
# ['난재밋', '게', '봤는', '뎅', '봉태규', '씨', '좋아용']
# ['별로']
# ['20', '대', '초반', '때', '이', '영화', '를', '봤을', '땐', '그저', '브리', '짓', '을', '연기', '한', '르네', '가', '넘', '사랑스러워서', '좋았다', '하지만', '10년', '후', '이', '영화', '를', '보는데', '뼛속깊', '이', '콕콕', '박힌다', '어쩜', '이렇게', '공감', '이', '되는지', '워킹타이틀', '필름', '의', '최고', '의', '수혜', '작이라면', '당연히', '난', '브리', '짓', '존스', '의', '일기', '라', '생각']
# ['재밋음', '근데', '마지막', '에', '여자', '는', '가족', '선택', '하고', '남편', '이', '이해', '해주는거', '임']
# ['왜', '우리나라', '는', '이렇게', '못', '만들까', '스몰빌', '중독증', '걸림']
# ['우승상금', '5억', '이아깝다진짜아깝다박재정씨기부하면안되나']
# ['조금', '진부한', '느낌', '이', '있었지만', '영화', '자체', '는', '신선하고', '재미있었다', '그리고', '열린', '결말', '이라니', '열린', '결말', '이라고', '생각', '하', '신분', '들', '은', '다시', '봐', '야할듯']
# ['송새벽', '한계', '는', '멀지', '않았지', '게다가', '한국영', '화', '이제', '이딴', '스토리', '로는', '본전', '도', '못', '건진다']
# ['10', '점', '주는게', '미안한', '영화', '는', '이', '게', '처음', '인', '듯']
# ['재미없다', '1', '점', '먹어라']
# ['순수하게', '본다면', '괜찮은', '영화', '다', '근데', '음란', '마귀', '가', '씌', '인', '눈', '으로', '보니', '현실', '성', '이', '없다는', '둥', '너무', '성적', '이라는', '둥', '개', '소리', '가', '나오지', '영화', '에', '내용', '을', '읽을줄', '알아야지', '이런', '결말', '이', '겠지', '생각', '하고', '보다', '다른', '결말', '이', '나왔다고', '욕', '하는거랑', '뭐', '가', '다른', '가']
# ['허수경', '씨', '자식', '농사', '잘', '하셨', '네', '용', '맘', '고생', '많으셨던', '만큼', '앞', '으로', '행복하시길', '바', '래', '요']
# ['명박', '스럽다']
# ['최악', '이다', '요리', '대회', '가', '중심', '으로', '살아나지도', '못', '하고', '주인공', '등', '의', '감', '정선', '또한', '어거지']
# ['재미', '하나', '도', '없다']
# ['각자', '의', '아픔', '을', '가지', '고', '하나', '의', '이상향', '같은', '섬', '에', '간다']
# ['흥미진진', '글구', '재밌어', 'ㅇ', 'ㄷ']
# ['무조건', '10', '점', '100', '점', '주고', '싶으나', '10', '점', '이', '최고점', '수라', '아쉽습니다']
# ['최근', '에', '나온', '어린이', '주연', '의', '영화', '개', '를', '훔치는', '완벽한', '방법', '이랑', '비교', '해보면', '답', '이', '나옴', '언제나', '마지막', '에', '신파', '만', '보여주면', '내용', '이나', '연출', '연기', '는', '상관없이', '별', '점', '10', '점', '달', '아대', '는', '단순', '무식한', '한국', '영화', '관객']
# ['오지호', '와', '영구', '와', '땡', '칠이', '들', '의', '얼음', '나르기', '대', '작전']
# ['굉장히', '재밌게', '본', '기억', '이', '남']
# ['DVD', '로', '빌려', '봤는데', '정말', '시간', '이', '아깝다']
# ['사후세계', '의', '묘사', '는', '정말', '최악', '그나마', '있던', '모든', '장점', '을', '한', '방', '에', '날려', '먹음']
# ['치밀한', '구성', '반복', '과', '인식', '의', '미학', '세상', '인생', '삶', '의', '아이러니', '들']
# ['좋았어요', '또', '보고싶네요']
# ['갑작스러', '온', '앤딩', '멀', '보여준거지']
# ['간만', '에', '옛', '액션영화', '보는', '기분', 'ㅋㅋ', '평점', '은', '너무', '낮아서', '10', '점', '드림']
# ['뭐', '하자는', '거지', '관객', '을', '우롱', '하는', '영화', 'ㅡㅡ']
# ['나', '홀로', '집', '에', '랑', '비슷한거', '같아요', 'ㅋㅋ', '엄청', '봤다는', '집', '에', '책', '두', '있어요', 'ㅋㅋ']
# ['과거', '엔', '이런', '영화', '를', '보면', '우리', '와는', '별개', '의', '것', '이라는', '생각', '이', '들었는데', '요즘', '은', '지금', '의', '현실', '로', '다가오는', '느낌', '은', '나', '만', '느끼는건', '아닌듯', '하다']
# ['사', '전', '정보', '없이', '봤음에도', '억지스러운', '스토리', '연결', '깔끔하지도', '유쾌하지도', '이도', '저', '도', '아닌']
# ['말로', '표현', '할', '수', '없는', '수작']
# ['겉멋', '만', '들어가지고']
# ['아무', '생각', '없는', '영화']
# ['제발', '좀', '한', '쿡', '영화', '반성', '좀', '하자']
# ['여배우', '너무', '귀', '여', '움', '엉뚱한', '캐릭터', '와', '신선한', '스토리', '가', '포인트']
# ['제목', '부터', '서비스', '가', '아닌', '써비스', '의도', '적', '으로', '80년', '대', '영화', '느낌', '으로', '만든', '건지는', '모르겠는데', '그냥', '지루하고', '평범하고', '모든', '것', '이', '너무', '구식', '이다', '특히', '음악', '은', '참아주기', '힘들', '정도', '로', '귀', '에', '거슬린다']
# ['북한', '과', '손잡고', '일본', '습격', '결국', '은', '일제시대', '일본', '이나', '한국', '이나', '똑같은', '놈되']
# ['명작']
# ['잘', '디렉팅된', '성장', '과정', '이', '볼', '만', '했다']
# ['어휴', '이', '게', '뭐', '냐']
# ['개', '지루하고', '여', '주인공', '도', '매우', '구리', '다']
# ['아이', '와', '함께', '보고왔습니다', '아이', '들', '이', '정말', '집중', '해서', '보더군요', '저', '도', '재미있게', '보았습니다', '토토', '너무', '귀여워']
# ['아니', '하지말라면', '하지말아야지', '자꾸', '말안', '듣고', '일', '커지게만', '듬', '보다가', '답답', '젤', '이해', '안되는게', '보호자', '죽고', '쫓기는', '상황', '에', '학교', '에서', '로맨스', 'ㅋㅋㅋㅋ', '기', '본', '세계관', '에', '대한', '설명', '도제', '대로', '안함', '책', '안', '읽은', '사람', '은', '어쩌라고', 'ㅋㅋ', '기대했는데', '망작']
# ['우왕', '최악', '이야', 'ㅠㅠ', '이런', '엉뚱한', '스토리', '전개']
# ['정지훈', '이', '당', 'ㅜㅜ', '보고싶다', '정지훈', 'ㅠㅠ']
# ['결국', '경찰', '들', '이', '한', '일', '은', '예수', '맡은', '애', '살린', '거', '하나']
# ['보는', '중', '에도', '내', '가', '이영화', '를', '왜끝', '까지', '보고있을까', '싶은', '영화', '태어나서', '정말', '이런', '영화', '처음', '나도', '영화감독', '이', '될수있을거', '같다']
# ['2시간', '27분', '짜리', '확장', '판', '으로', '봤다', '마이클', '매드', '슨', '연기', '는', '좋았다', '그러나', '김', '빠진', '연출', '능력', '과', '시나리오', '가', '명', '배우', '들', '의', '연기', '를', '하나', '도', '끌어내지', '못', '했다', '그리고', '카리스마', '없는', '캐릭터', '에', '알', '파치노', '는', '어울리지', '않는다']
# ['와', '왠만해', '선', '1', '점', '안주는데', 'ㅋㅋ', '독립영화', '아니냐', '이', '거']
# ['구', '스반', '산트', '의', '컬트', '로드무비', '아이다호', '난', '리버', '피닉스', '광팬', '였고', '그', '후', '리버', '피닉스', '의', '죽음', '으로', '매우', '힘들었던', '키', '아누', '리브', '스', '아직도', '생각나는', '영화', '마이', '오운', '프라이', '빗', '아이다호', '둘', '은', '별처럼', '빛나는', '전', '미', '최고', '의', '아이돌스타', '였다']
# ['일단', '보라', '내', '가', '무슨', '말', '이', '하고싶은지', '느끼게', '될', '것', '이다']
# ['이', '게', '영환', '가']
# ['최고', '였습니다', '여운', '이', '많이', '남는', '작품', '입니다']
# ['이런', '드라마', '또', '언제', '나올까', '무조건', '만점']
# ['어느', '민주화', '운동', '이', '총', '들', '고', '탱크', '타고', '정부', '한테', '뎀비', '지', '삼일', '만세', '운동', '때', '그렇게', '하', '데', '운동', '의', '의미', '를', '모르냐', '518', '은', '그냥', '반정부', '시위', '야', '그것', '도', '무력', '시위', '김대중', '이', '쿠데타', '실패하고', '핑계', '거리', '찾다가', '민주화', '운동', '이라고', '둔갑', '한거야']
# ['그림', '너무', '좋고', '교훈', '이', '되는', '멋진', '영화']
# ['많은걸', '느끼게', '해준', '영화']
# ['초', '중반', '의', '긴장감', '을', '허무하게', '만드는', '억지스런', '후반', '부']
# ['김태균', '은', '감독', '으로써', '의', '재능', '이', '의심', '된다']
# ['주몽', '에', '가려서', '빛', '을', '못', '본', '드라마', '지만', '정말', '정말', '재밌게', '본', '드라마']
# ['후회', '는', '없어요', '이제', '부터', '시작', '이니까', '당신', '과', '함께']
# ['웃으라고', '만든거', '맞지']
# ['빠걸', '이라', '참', '발음', '이']
# ['좀', '식상한', '스릴러', '영화']
# ['정말', '놀랍다', '어떻게', '주연', '4', '명', '이', '다', '국어', '책', '을', '읽는다']
# ['내', '가', '평생', '본', '애니', '영화', '중', '가장', '잔잔하고', '가장', '재미있었다']
# ['1', '점', '은', '아닌데', '평점', '조', '절용', '인도영화', '는', '유치', '뽕짝', '빼면', '시체', '다', '노래', '와', '신파', '인도', '무비', '의', '조미료']
# ['정말', '대단한', '영화', '다', '여운', '을', '많이', '남겨', '준다']
# ['장난', '하나', '처음', '부터', '끝', '까지', '쿵푸팬더', '랑', '똑같음', '표정', '도', '맞고', '쓰러지는것도', '같음']
# ['한예슬', '이', '목숨', '걸고', '연기', '하던', '시절', '다시', '한번', '그때', '처럼', '간절해질', '수', '는', '없나']
# ['ㅎ']
# ['반', '베트남전쟁', '영화', '중', '최고', '물론', '톰', '크루즈', '의', '최고', '의', '열연', '과', '함께']
# ['전', '흠뻑', '빠져서', '극장', '을', '세번', '을', '갔고', '오전', '에', '가서', '저녁', '에', '왔죠']
# ['그래도', '휴먼', '비즈니스', '는', '재밌었음']
# ['흔한', '이야기', '지만', '결코', '얄팍한', '감성', '에서', '나올', '수', '는', '없는', '절제', '된', '영화', '다', '내', '가', '시나리오', '작가라', '면', '죽기', '전', '에', '이런', '러브', '스토리', '를', '꼭', '쓰고', '싶을', '것', '같다']
# ['며칠', '전', '에', '다운', '받아', '봤는데', '태권도', '영화', '흔', '치', '않은데', '재밌게', '잘', '봤습니다']
# ['재미없을거', '같네요', '하하', '하']
# ['적당하다', '끝', '까지', '누군지', '모르겠다']
# ['여러', '흥행', '작', '들', '을', '짜집기', '한', '듯', '한', '스토리', '에', 'TV', '특집', '극', '수준', '의', '발퀄']
# ['평점', '이', '너무', '높다', '10', '점주', '는', '양심', '도', '없는', '것', '들', '아']
# ['굿']
# ['내', '인생', '의', '최악', '의', '영화', 'ktx', '좌석', '없어', '시네마', '석', '타면서', '보았는데', '영구', '와', '땡', '칠이', '가', 'x', '10000', '배잼남']
# ['보는', '동안', '내내', '좋드', '라']
# ['엔딩', '부분', '만', '인상', '적', '인', '하이', '틴', '슬래셔', '무비']
# ['그냥', '병맛', '영화', '솔직히', '영화', '라고', '부르기', '조차', '영화', '라는', '그', '단어', '에', '미안하다', '이런', '것', '도', '감독', '이라고', '어디가', '서', '신인', '여배우', '꼬시면', '서', '깝', '치겠지', '이', '영화', '생각', '만', '나면', '자다가도', '웃기는', '영화', '엉', '성하기', '로는', '심형래', '의', '초기', '작', '이나', '남기남', '감독', '영화', '쯤', '되야', '명함', '을', '내', '밀', '만', '한', '수준', '이다']
# ['지구', '상의', '모든', '영화', '를', '위해', '1등', '해라']
# ['인상', '적', '인', '영화']
# ['완전', '감동', 'ㅜㅜㅜㅜ', '아무리', '봐도', '감동', '감동', 'ㅠㅠㅠ']
# ['여전히', '최고다', '최고', '의', '스릴러']
# ['작가', '감독', '배우', '모두', '최고', '입니다']
# ['이건', '뭐']
# ['제목', '에', '낚였어', '지루하고', '발랄하지도', '않고']
# ['알바', '장난', '하나', '이딴', '게', '잼있니']
# ['일본', '의', 'SF', '호러', '애니메이션', 'LILY', 'C', 'A', 'T', '을', '모티브', '로', '삼아', '제작', '한', '영화', '입니다']
# ['전원주', '때문', '에', '안', '봅니다', '영화', '내용', '이', '어떤지는', '모르지만']
# ['잘만', '든', '영화', '브라보', '재미있습니다']
# ['몰입도', '가', '대단한', '영화', '다', '주인공', '의', '인생', '을', '바로', '옆', '에서', '같이', '겪은', '느낌', '을', '주는', '영화', '추천']
# ['아', '정말', '너무', '좋은', '영화', '다']
# ['처음', '에', '볼때', '는', '이해', '가', '안', '갔는데', '한두', '살', '먹고', '다시', '보니', '아', '휘', '의', '사랑', '에', '먹', '먹해', '졌다', '세번', '째', '로', '볼때', '는', '눈물', '을', '훔치면서', '봤다']
# ['그때', '봤을', '때', '도', '재미있었고', '지금', '봐도', '재밌는', '영화', '가장', '좋아하는', '애니메이션']
# ['일본', '에서', '10', '주년', '극장판', '만드는데', '우리나라', '에선', '10', '주년', '으로', '재개', '봉하', '니', '이건', '좀', 'ㅄ', '아님']
# ['신은', '멀리', '있는게', '아니라', '우리', '주변', '에', '가까이', '있는거네요']
# ['관객', '조롱', '하', '냐', '1', '점도', '아깝다']
# ['CG', '가', '참', '어색했던', '영화']
# ['이', '거', '재미없다는', '사람', '은', '도대체', '뭐', '지', '재밌습니다', '바보', '아니라면']
# ['최고']
# ['극장', '에서', '정말', '재밌게', '본', '기억', '이', '있는데', '평점', '이', '너무', '낮다', '나이', '먹어', '다시', '봐도', '인크레더블', '헐크', '보다는', '더', '나은것', '같음']
# ['과연', '심플', '2000']
# ['너무', '재밌어서', '역사', '공부', '하게', '만드는']
# ['착한', '영화', '그리고', '재미없습니다']
# ['정말', '뜻', '이', '깊습니다']
# ['이야', '미키', '루크', '나오는', '홈', '보이', '영화', '를', '다', '아는', '분', '들', '이', '계시', '네', '이야', '놀', '라울', '뿐']
# ['명작', '이라', '불러도', '손색', '이', '없는', '영화', '임']
# ['진짜', '추천', '해요']
# ['이', '게', '진실', '이다']
# ['놀러왓음']
# ['포스터', '보고', '낚임', '다코타', '패닝', '볼려고', '봤는데', '뒤', '에', '잠깐', '7분', '정도', '나오고', '끝', 'ㅠ', '광고', '용', '포스터', '임']
# ['양갈래', '딴', '분녀', '의', '다리', '벌려', '품어주기']
# ['다', '들고나가']
# ['영화', '가', '어이없음', '보시', '고', '욕', '하지말고', '그냥', '보지', '마세요', '입', '만', '더러워짐']
# ['난', '남자', '라서', '유아인', '별로', '좋아하진', '않지만', '그래도', '배우', '들', '연기', '가', '편집', '과', '억지스런', '설정', '과', '대사', '를', '뛰어넘을만큼', '훌륭했음', '그렇게', '막', '까', '일', '정도', '는', '아니라고', '생각', '함']
# ['정말', '재미나', '게', '아이', '들', '이', '보더라구요', 'ㅎㅎ', '아기', '독수리', '너무', '귀여워요', 'ㅎㅎ']
# ['재밌을', '뻔', '한', '영화', '송강호', '가', '낭비', '된', '느낌']
# ['제일', '좋아하는', '영화', '임']
# ['보고', '보고', '또', '봐도', '쩐다', '그냥', '근데', '평론가', '라는', '인간', '들', '은', '재밋는', '영화', '가', '있긴하냐']
# ['여운', '이', '남는', '아련한', '영화']
# ['장끌', '로드', '의', '몰락', '을', '가져온', '오우삼', '헐리우드', '작품', '중', '가장', '재미없었던', '졸작']
# ['전설', '의', '첩보', '영화', '시리즈', '의', '시작']
# ['진짜', '강추', 'ㅠㅠ', '넘', '잼', '서여']
# ['제작비', '가', '아까운', '영화', 'ㅠ', '안쓰럽다']
# ['꾀', '재미있네요', 'ㅋ', '근데', '상대', '팀', '중', '에', '한', '명', '이름', '을', '모르겠네요']
# ['엉', '성', '한', '스토리', '배우', '들', '이', '묻혓다']
# ['우웩볼', '작품', '중', '에서', '그나마', '볼', '만은', '하네']
# ['케이블', '영화']
# ['포장', '담당', '요정', 'ㅎㅎ', '너무', '귀엽고', '재밌었습니다', '더빙', '이', '더', '재밌어요']
# ['아', '놔', '유인나', '는', '매화', '존나', '귀척', '이쁜', '척', '하고', '그것', '밖에', '할', '줄', '모르냐', '연기', '진짜', '그러니까', '결국', '두', '남자', '사이', '에서', '어장', '관리', '만', '하는', '걸', '로', '보이지', '게다가', '드라마', '내용', '만', '질질', '끌', '고', '유인나', '캐릭터', '는', '드라마', '를', '위', '한', '연기', '가', '아니라', '본인', '피알', '을', '위', '한', '연기', '다']
# ['외설', '을', '보며', '예술', '이라', '하고', '예술', '을', '보고', '외설', '이라', '하는', '나라', '에서', '태어난', '사람', '이', '감독', '이', '되어', '만든', '영환', '데', '재밌겠냐']
# ['어릴', '때', '비디오', '빌려', '봤던', '기억', '이']
# ['케이블', '에서', '틀어줄', '때', '마다', '보는데도', '질리', '지', '않는', '몇', '안되는', '영화', '드루', '와', '드루', '와']
# ['한수연', '씨', '진짜', '매력', '적', '이야']
# ['차라리', 'NGC', '우주', '다큐멘터리', '봐라', '휠씬', '더', '잼있다']
# ['평점', '만', '믿고', '보았는데', '대사', '많고', '지루합니다', '추격', '장면', '도', '예고편', '이', '다', '구', '요', '영', '화보', '는', '전체', '의', '몰입도', '가', '애', '들', '도', '중간', '에', '나가던데', '어떻게', '이', '평점', '이', '죠', '9', '점', '이상', '주신', '분들', '너무하세요', '실제', '는', '6', '점', '정도', '인', '듯해', '요', '캐릭터', '가', '귀엽고', '이뻐서', '그나마']
# ['한국', '드라마', '의', '혁명', '이자', '수작', '윤주희', '를', '알', '게', '해준', '작품']
# ['꼭', '사랑', '하는', '이성', '이', '아니더라도', '나를', '좋아해', '주는', '사람', '이', '주변', '에', '있다는', '것', '은', '정말', '감사한', '일이', '다']
# ['분하다', '점수', '에', '낚였다']
# ['내용', '에', '진전', '이', '없어요', '맨날', '똑같아요', '희망이', '없는', '루나', '빠른', '전개', '를', '원해요', '현실', '성', '있는', '내용', '으로', '원해요']
# ['0', '1', '점', '은', '없네', '아쉽다']
# ['완벽해', '이런', '얘기', '너무', '좋아', '인도영화', 'sehr', 'gut']
# ['재밌는데', '굿']
# ['재밌음', '바람', '은', '피우면', '안됨']
# ['최정윤', '씨', '가', '젤', '이쁜디', '참', '역할', '이', '안타깝네요', 'ㅎ']
# ['로맨틱', '드라마', '좋아하는데', '재밌게', '봤어요', '이런', '영화', '너무', '좋아요']
# ['사회', '의', '한', '아픈', '곳', '을', '매만지는데', '아프지가', '않고', '느낌', '이', '좋았다', '최우식', '의', '연기', '도', '좋았고', '부족한', '부분', '없이', '잘', '만든', '작품', '이다']
# ['별로', '였음']
# ['별', '반도', '주기도', '아까', '움']
# ['어이', '없다', '마지막', '에', '무섭지도', '않자나']
# ['남주', '류덕환', '인', '줄', '연출', '연기', '스토리', '시사', '점', '다', '좋았다', '마무리', '만', '옥', '의', '티', '독립영화', '의', '바람직한', '길', '을', '제시', '했음', '잼있어요']
# ['노래', '연출', '연기', '캐릭터', '설정', '배경', '스토리', '구성', '머', '하나', '빠질게', '없다', '그야말로', '완벽한', '영화', '다', '혁명', '적', '인', '영화', '멋진', '영화', '머', '라', '다', '표현', '할수', '없', '음', '에', '안타까울', '뿐']
# ['박진희', '최고', 'ㅋ']
# ['뭐', '냐', '이', '거', '뭐', '야', '뭐', '야', '뭐', '야']
# ['몇번', '을', '봐도', '재밌어요']
# ['쓰래', '기', '다', 'ㅡㅡ', '무슨', '목적', '인지', '전반', '엔', '먼가', '좀있을줄', '알았더니', '후반', '으로', '갈수록']
# ['이영화', '를', '볼때', '관점', '을', '주인공', '에', '두어라', '그럼', '정말', '최고', '의', '공포', '영화', '가', '될것이다']
# ['평점', '낮게', '준', '애', '들', '대부분', '잔인하다고', '영화', '제대로', '보지', '도', '않고', '내용', '이해', '못', '한', '애', '들', '이', '태반', '이라는', '것', '확신', '한다']
# ['단순히', '줄리아', '로버츠', '라는', '여배우', '의', '힘', '만으로', '끌', '고', '가기', '에는', '러닝', '타임', '내내', '너무', '버겁다']
# ['휴', '내용', '이', '욕심', '이', '많으', '신건', '지', '이건', '정말', '이', '영화', '나누면', '주먹', '영화', '청춘영화', '가족영화', '세', '가지', '영화', '는', '나올것', '같은데', '내용', '이', '조화', '도', '없이', '여기', '서', '펑', '저', '기', '서', '펑', '그래도', '끝', '까지', '봤지만', '휴', '별', '많은', '평점', '은', '진짜', '알반', '가요']
# ['기발한', '소재', '내용', '전개', '를', '왜', '이렇게', '하지']
# ['기', '대안', '하고', '봤는데', '정말', '잘', '봤습니다']
# ['아', '나', '명대사', '존나', '욱겨', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['여운', '이', '남는', '아름다운', '영화']
# ['집중', '하고', '몰입', '하면', '6', '점', '대', '평점', '이', '나올리', '없다', '본다', '충분히', '멋진', '작품', '이었다']
# ['마돈나', '가', '여자', '주인공', '인', '것', '부터가', '에러', '다']
# ['아직', '보기전이지만', '재미', '날듯', 'ㅋㅋㅋ']
# ['현빈', '과', '이연희', '정말', '멋있었다', '잔잔한', '감동', '을', '전', '해준', '참', '착한', '영화', '였다']
# ['초반', '의', '상황', '은', '재미있었지만', '그게', '다다']
# ['정말', '절박', '한', '상황', '이어도', '긍정', '적', '이고', '이', '것', '저', '것', '너무', '재밌네요']
# ['글쎄요']
# ['찰스', '자비', '에르', '와', '에릭', '렌셔', '의', '가치관', '차이', '와', '갈등', '그리고', '갈라', '서게', '된', '배경', '을', '설득', '력', '있게', '그려', '낸', '수작']
# ['이', '좋은', '스토리', '로', '이런', '망작', '이', '탄생', '하다니']
# ['성냥', '팔이', '이후', '이런', '느낌', '처음', '이야', 'ㅠㅠ']
# ['스릴러', '라고', '하기엔', '민망한', '수준', '그렇다고', '야하길', '하나']
# ['오랜', '만', '에', '2', '번', '봐도', '아깝지', '않은', '영화', '발견']
# ['정체', '성', '이', '모호한', '분노', '가', '빠진', '그냥', '질주']
# ['음울', '에', '로', '틱', '그리고', '쇼킹함']
# ['영원히', '사요나라']
# ['참내', '뭐', '하자는거']
# ['정말', '소름끼친다']
# ['열심히', '싸웠으나', '그냥', '열심히', '일', '뿐']
# ['한국판', '노팅힐', '실', '은', '노팅힐', '보다', '먼저', '나왔지만', '언젠가', '는', '다시', '보고싶은', '임창정', '의', '멜로', '연기']
# ['발연기', '막장', '허', '술', '한', '스토리']
# ['시도', '는', '좋았다', '하지만', '해외', '에', '이런', '류', '영화', '에', '비해', '많이', '떨어지는건', '사실', '이다']
# ['아', '투명인간', '아저씨', '연기', '쩔어', '진짜', '역시', '짱']
# ['오오', '미', '지려부렷소', 'ㅜㅜ', '감동', '적', '인', '영화']
# ['전반', '적', '으로', '드라마', '스토리', '의', '질', '을', '높여야', '한다', '공상', '소설', '이', '아니고서는', '그리고', '말', '도', '안되는', '소재', '로', '질질', '끄는', '전개', '는', '짜증']
# ['지니', '를', '닮아', '시종일관', '에너지', '가', '넘쳐', '흐른다', '정말', '신나게', '볼', '수', '있는', '명작', '지니', '와', '자스민', '은', '언제', '봐도', '매력', '적', '이다']
# ['엔딩씬', '의', '불꽃놀이', '처럼', '찬란한', '사랑', '의', '시작', '과', '소멸', '을', '두', '배우', '의', '명연기', '에', '의해', '스크린', '에서', '눈', '을', '뗼수없', '게', '만든다', '라이언', '고', '슬링', '이', '부른', '주제가', '도', '너무', '좋았다', '이기', '적', '현실', '적', '으로', '변해가는', '여자', '와', '가족', '이', '최', '우선', '이지만', '갈수록', '찌질해지는', '남자', '의', '거리', '는', '너무', '멀어', '보인다']
# ['어렷', '을', '때', '동화', '를', '읽은', '느낌', '을', '성인', '이', '되서', '느꼈다고', '할까', '계속', '생각남']
# ['평점', '이', '너무', '낮아서', '10', '점줌', '8', '5', '정도', '가', '적당한듯']
# ['WTF']
# ['뭐', '가', '퍼펙트', '하다는', '것', '인지']
# ['볼수록', '빠져드는', '드라마', '일요일', '이', '기다려지는', '이유']
# ['존잼', '추억', '이다']
# ['꺄악', '이건', '넘으', '뭐라', '신선한', '충격', '이었다', '마무리', '는', '아주', '조금', '아쉽지만']
# ['요즘', '볼', '만', '한', '영화', '없나']
# ['오유', '에서', '왔는데', '진짜', '답', '없음']
# ['개', 'OO', '은', '영화']
# ['what', 'the', 'fuck', '이', '건아', '니', '자', '나', '진짜', '0', '점', '없나', '시간', '이', '아깝']
# ['며칠', '째', '계속', '마음', '에', '남아', '요']
# ['최고', '의', '암살자', '들', '이', '모여', '최고', '를', '가릴줄', '알았는데', '볼', '만', '한', '데']
# ['ㅋㅋㅋ', '재미', '잇쩡', 'ㅋ', '역시', '이범수', 'ㅋㅋ']
# ['제', '가', '연기', '를', '논', '할', '자격', '은', '없지만', '명연기', '로', '멋진', '드라마', '보게', '해주셔서', '감사합니다', '드라마', '자체', '를', '잘', '안보', '는', '편', '인데', '파스타', '골든타임', '보', '니까', '왜안', '봤을까', '싶네요', '감사합니다']
# ['정말', '재미있는', '시리즈', '최고']
# ['아', '진짜', '이', '시간', '에', '차라리', '아무', '것', '도', '안', '하고', '누워', '있는게', '더', '나음']
# ['그래픽', '은', '잘', '모르겠는데', '스토리', '는', '영화', '를', '잘', '모르는', '내', '가', '봐도', '최악', '이', '였음']
# ['우리', '주변', '에서', '이렇게', '아무렇지', '않게', '잔혹', '이', '자행', '되고', '있다는', '블랙코미디']
# ['말', '이', '필요없는', '내', '인생', '최고', '의', '영화']
# ['이런', '컨셉', '이', '면', '최소한', '현실', '성', '에', '기반', '을', '두는데', '이건', '공상', '을', '넘어선', '허상', '킬링', '탐', '용도', '안됨', '잠이안와', '서', '뭔가', '하나', '라도', '스킵', '해가면서', '보려느', '목적', '이라도', '이건', '보지', '마소', '짜증나서', '잠', '이', '깰듯', '내', '가', '이', '거', '호주', '에서', '봤는데', '이', '거', '다', '욕', '했음', '밑엣놈', '은', '그저', '한국', '까는', '한국', '쓰레기']
# ['억지스러운', '면', '이', '있지만', '보는내내', '좋았다']
# ['너무', '많은것을', '보여주려다', '뒤죽박죽', '엉', '켜', '버린', '느낌']
# ['진짜', '평점', '하나', '도', '아깝다', '지금', '40분', '보고있는데', '지루함', '의', '극치', '다', '제작비', '가', '들어가긴', '했음', '오버', '스러운', '연기', '토', '가', '나올', '뻔함']
# ['어린', '시절', '엄마', '와', '함께', '영화관', '에서', '봤던', '최고', '의', '애니메이션']
# ['말', '이', '필요없다', '한마디', '로', '최고']
# ['짱', '재미', '이', '씀']
# ['재미', '도', '감동', '도', '없네']
# ['후회', '없네여', '강렬했어요']
# ['찐자', '재밌는', '영화', '다']
# ['평점', '이', '생각', '보다', '너무', '낮다', '7', '5', '점', '정도', '상향', '조', '정이', '필요함', '별', '생각', '없이', '봤는데', '꽤', '나', '재밌었음']
# ['0', '점', '주고', '싶음']
# ['우리', '고향', '내', '가', '가본', '곳', '이', '주무', '대로', '나오고', '감동', '있었습니다', '태안', '꽃게', '다리', '와', '삼길', '포', '마지막', '씬', '이', '감동', '임']
# ['최근영', '화', '에서', '느끼는', '아련한', '고전', '의', '기분', '남자', '주인공', '이', '시간', '적', '배경', '이', '비슷한', '다른', '영화', '사랑', '은비', '를', '타고', '의', '진', '켈리', '와', '비슷하기까지']
# ['정말', '재밌게', '봤네요', '자칫', '지루하기', '쉬운', '영화', '를', '시간대', '를', '이리저리', '섞어서']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '어릴', '때', '보고또보고', '또', '보고', '또', '봐도', '안', '질러던', '영화']
# ['학창시절', '연습장', '에', '마구', '갈겨', '댄', '낙서', '를', '어른', '이', '되고', '본', '후', '낯', '뜨거워지는', '예']
# ['영화', '과', '학생', '이', '습작', '한', '듯', '한', '완성', '도', '유준상', '포함', '연기력', '망쪼', '시나리오', '망쪼', '연출', '력', '망쪼', '별', '점', '을', '준다는', '것', '자체', '가', '의미', '없음', '잔인한', '영화', '에', '대한', '거부', '감은', '없으나', '허', '접', '한', '영화', '에', '대한', '거부', '감은', '분노', '로', '까지', '이어지고', '영화', '발', '로', '만들었다', '유준상', '이']
# ['진짜', '웃기', '면', '몰라', '재미있지도', '않고']
# ['당시', '여성', '들', '의', '현실', '을', '반영', '하고', '있어', '씁쓸하다']
# ['ㅉㅉㅉㅉㅉ', '진짜', '뭐', '니', '0', '점', '하고', '등록', '누르는데', '평점', '입력', '하', '라는', '문구', '뜰', '때', '마다', '화면', '부셔', '버리고', '싶다']
# ['여배우', '노력', '한', '거', '10', '점']
# ['추모', '의', '의도', '는', '좋았으나', '너무', '지루하고', '연기자', '들', '연', '기', '땜', '에', '못', '봐줄', '정도', '마지막', '장', '면', '땜', '에', '봄']
# ['소재', '만', '신비롭지', '영상', '내용', '그리고', '배경음악', '등', '이', '왜', '이', '리도', '촌스럽고', '허', '접하게만', '보이', '고', '느껴지던지']
# ['임', '형', '빈', '같은', '사랑', '이', '있을', '수', '는', '있다', '그렇지만', '여러', '남자', '를', '전전', '하는', '속', '된', '말로', '화', '냥', '끼', '있는', '윤주', '에', '대해', '그렇게', '집착', '하는', '모습', '이', '얼마나', '개연', '성', '있는지는', '모르겠다', '장편', '소설', '로', '읽으면', '모르겠지만', '한편', '의', '영화', '로는', '윤주', '라는', '인물', '에', '공감', '하지', '못', '하겠다']
# ['우와', '대박']
# ['좀', '뻔한', '스토리', '스케일', '큰것두', '아니고']
# ['동참', '할게요', '파이']
# ['분명한건', '금연', '운동', '에', '별', '도움', '이', '될것', '같지', '않다는거', '높은', '평점', '은', '이해', '가', '안됨']
# ['초반', '에는', '재밌었는데', '갈수록', '이상해진다']
# ['이영화', '가', '강간범', '이', '출연', '한', '영화', '맞나요', '인생', '퇴갤', '되신', '것', '을', '추카', '합니다']
# ['아주', '재미있게', '봤어요', '유덕화', '너무', '멋있', '습', '니', '댰']
# ['액션', '신', '만', '괜찮다', '근데', '여', '주인공', '살인마', '인데', '아이러니', '하다']
# ['맹꽁', '치', '때문', '에', '프로그램', '이', '확', '맛', '이', '갔네요']
# ['성룡', '최고']
# ['초', '난감합니다']
# ['이건', '뭐', '무슨', '내용', '인지도', '모르겠고', '재미', '도', '없고', '지루하고', '이런', '영화', '왜만듬']
# ['만화', '코스프레', '를', '뛰어넘어', '연기', '와', '액션', '이', '최상', '을', '선보이고', '있다']
# ['이런', '식', '의', '영화', '는', '제목', '을', '굳이', '람보', '로', '붙일', '필요', '도', '없지', '않을까']
# ['잔잔하고', '볼', '만', '함니다']
# ['이', '걸', '보고', '어떤', '계획', '을', '집어치우게', '되었다', '정말', '감사하다']
# ['정말', '째밌어', '요', '판타지', '한', '영화']
# ['굿']
# ['재미', '졸라', '없음', '지루하고']
# ['ㅋㅋㅋㅋㅋ', '찰리', '의', '사이렌']
# ['잼', '잇네', '특유', '의', '맛', '이', '잇네']
# ['본', '지도', '오래되고', '기억', '도', '별로', '없지만', '진짜', '수준', '낮은', '영화인', '것', '으로', '기억', '함', '김민종', '처럼', '지진희', '도', '영화', '는', '안', '맞는', '듯', '이', '영화', '는', '특히', '나', '아니였음']
# ['이', '시대', '가', '군중', '속', '에서', '외로움', '을', '느끼는', '세계', '라', '는걸', '예견', '한', '걸까', '15년', '이', '지난', '지금', '고독', '함', '은', '더욱', '가속', '화', '되었지']
# ['예전', '영화', '라', '그런지', '완죤', '재미없는디']
# ['베드', '신', '하나', '는', '진짜', '리얼', '하네', '끝']
# ['어릴', '적', '케이블', '에서', '살짝', '봤습니다', '심', '감독', '님', '같은', '시기', '의', '영화', '로는', '쥬라기', '공원']
# ['진짜', '쓰래', '기', '드라마', '이다', '작가', '는', '무슨', '생각', '으로', '이런', '걸', '썻을까', '암', '걸릴거', '같은', '드라마', '다', '개비', '추이', '다']
# ['너', '신고', '요']
# ['엄청난', '긴장감', '과', '몰입도']
# ['재밌던데']
# ['엘리샤', '커스버트', '이쁨', '그것', '뿐', '이다']
# ['재미없음']
# ['보진', '않았지만', '재밌네요', 'ㅎㅎ']
# ['불후', '의', '명작', '뮤지컬', '을', '보고', '이따위', '평점', '을', '주는', '내', '가', '잘', '못', '된', '거', '다']
# ['어릴', '때', '굉장히', '감명', '깊게', '봤는데', '이제', '보니', '레이', '리', '요', '타였구나']
# ['20년', '전엔', '보통', '여고생', '의', '이야기', '를', '다룬', '작품', '은', '거의', '없었다', '특히', '이쁘지도', '몸매', '가', '잘빠지지도', '공부', '를', '잘', '하지', '못', '하는', '여고생', '의', '절대다수', '를', '차지', '하는', '이', '들', '의', '이야기', '가', '없었더니', '참', '아이러니', '한', '상황', '에서', '나온', '한', '줄기', '빛', '같은', '영화']
# ['사형', '집행', '전', '존', '의', '대사', '가', '떠오른다', '모든', '것', '이', '지쳤다고', '말', '하는', '존', '의', '모습', '을', '보고', '눈물', '이', '났다']
# ['걍', '봐']
# ['당시', '선풍', '적', '인', '인기', '를', '끌었던', '기억', '이']
# ['유명', '가수', '까지', '마라', '진짜', '한국', '노답', '이다']
# ['라스트', '씬', '에서', '눈물', '이', '흘렀다']
# ['고', '잉', '메리', '와의', '추억', '은', '원피스', '와', '나이', '를', '같이', '먹은', '우리', '들', '한테', '도', '있재']
# ['어라', '갑자기', '저', '게', '뭐', '지', '응', '저건', '무슨', '상황', '과', '같은', '의문', '이', '중간', '중간', '계속', '든다', '즉', '감독', '의', '연출', '부족', '그리고', '스토리', '도', '콜하스', '의', '신념', '이', '감동', '스러운', '것', '도', '아니고', '철학', '적', '의미', '표현', '이', '깊은', '것', '도', '아니고', '이', '게', '왜', '평점', '이', '7', '9', '나', '되는지', '이해', '불가']
# ['이', '영화', '를', '같이', '본', '여자', '와', '사겼어요']
# ['둘이서', '게임', '하는', '내내', '흥미진진', '했음', '근데', '뒷', '부분', '내용', '전개', '는', '좀', '그래도', '재밌', '따']
# ['점점', '흥미롭네요', '흔한', '배신', '복수', '없이도', '이리', '재미나다', '니', '이런', '가족', '드라마', '많이', '제작', '되길', '바라', '요']
# ['너무', '그래픽', '으로', '후', '까시를', '잡았음', '어색한', '액션']
# ['흥미로워', '보이는', '설정', '도', '너무나도', '과장', '된', '액션', '과', '진부한', '진행', '을', '만나서', '결국', '재미', '를', '잃고', '만다']
# ['가까스로', '유효', '타', '하나', '를', '만들어', '낸', '연결', '고리', '와', '룰']
# ['다소', '억지', '가', '강한', '설정', '그리고', '개인', '적', '으로', '싫어하는', '배우', '가', '나와서', '어쨌든', '이웃', '사촌', '이라는', '개념', '이', '희미해져', '가고', '있는', '시대', '적', '상황', '속', '에서', '방관', '자', '의', '자세', '로', '나', '몰라라', '하는', '시민', '의식', '에', '좋은', '메시지', '이기는', '함']
# ['연기', '가', '영화', '를', '정말', '살렸다']
# ['도라에몽', '최고']
# ['쿡', '방이', '고', '먹방', '이고', '보고나면', '흐뭇하게', '웃게', '되는', '그런', '영화']
# ['볼놈', '은', '봐', 'ㅋㅋ', '후회', '할껄']
# ['코메디', '를', '뚫었다']
# ['정말', '재밌어요', '이미', '죽은', '사람', '들이였다니', '결말', '보고', '어이없어서', '후기', '보고', '이해', '됬습니다']
# ['네', '노잼', '중', '에', '개', '상', '노잼', '핵', '노잼', '이', '죠']
# ['라스트', '30분', '은', '엄청난', '에너지', '와', '카타르', '시스', '폭발']
# ['관객', '은', '안중', '에도', '없이', '지', '들', '끼리', '하', '는', '은행강도', '놀이']
# ['아동', '들', '이', '보기', '에는', '재밌는', '영화', '그럭저럭', '교훈', '을', '줌', '어른', '이', '보기', '엔', '재미없음']
# ['아랍', '쪽', '뉴스', '에', '나온것', '들', '다', '풀어놨네', '에에', '에', 'ㅋ', 'ㅋ']
# ['누가', '4', '45', '로', '만들었어']
# ['처음', '유치하다고', '생각', '했는데', '배우', '들이', '잘', '하고', '눈물', '나와요']
# ['다수', '의', '평점', '은', '항상', '옮', '은', '것', '같다', '평점', '을', '보고', '영화', '를', '고르는', '것', '이', '항상', '정답', '은', '아니지만', '높은', '평점', '이', '줄줄이', '달린', '영화', '는', '이유', '가', '있는', '것', '같다내', '인생', '베스트', '에', '꼽히는', '영화']
# ['이', '게', '왜', '19', '금', '이지', '글', '고', '영화', '보는데', '집중', '이', '안됨', 'ㅋㅋ', '노래', '부르니', '무슨', '디즈니', '애니', '보는거', '같음']
# ['공포', '의', '터미네이터', '주', '지사', '님', '2', '명']
# ['어렸을', '때', '봐서', '몰랐는데', '다시', '보니', '너무', '슬픈', '영화', '10년', '전', '영화', '인데', '도', '영상', '미가', '너무', '예쁘다']
# ['캬', '이건', '뭐', '역대', '급', '영화', '똥', '이나', '퍼', '먹어라']
# ['과시', '욕', '가득한', '시나리오', '에', '허', '접', '한', '마멧', '의', '연출', '조', '맨테나의', '발연기', '완벽하게', '3', '박자', '가', '들어맞다']
# ['티비', '에서', '보고', '감동', '먹었다']
# ['관객', '이', '다', '보고', '있는데', '저', '뜬금', '없는', '결말', '이란', '초능력', '으로', '죽인것', '외', '엔', '달리', '설명', '할수가', '없네']
# ['중세', '시대', '배경', '의', '좀비', '물', '충분히', '매력', '적', '인', '요소', '를', '가지', '고', '이런', '쓰', '렉', '이', '수준', '이라니', 'ㅋㅋ']
# ['영화', '드럽게', '막장', '에', '노잼', '이지만', '웃겼으니']
# ['그냥', '보면서', '머리', '가', '텅', '빈다']
# ['한혜진', '기성용', '새끼', '랑', '만난다는거', '보고안', '봣', '는데꺼진다니', '이제', '다시', '매주', '시청', '하', '겟음', 'ㅋㅋㅋ', '얼굴', '도', '보기', '싫', '엇음', '둘다', 'ㅋ', '진작', '바꿧', '어', '야', '죠', '제작', '진', '들', 'ㅋ']
# ['일단', '한숨', '자고', '일어나서', '뵙겠습니다', '갑사', '합니다']
# ['마음', '이', '짠하다', '엄마', '한테', '더', '잘해야', '지']
# ['공포', '와', '스릴', '을', '찾아', '볼', '수', '없는', '공포', '스릴러', '영화']
# ['성악', '한', '인간', '의', '본성', '을', '여실히', '보여줬다', '하지만', '과장', '된', '연출', '이', '마이너스', '요소', '다']
# ['이제', '는', '모니터', '에서', '처녀', '가', '나오면', '플랜카드', '들고', '환영', '해줄', '자신있다']
# ['최악', '이다']
# ['내', '휴일', '을', '망처', '버린', '악', '중', '에', '최악', '의', '영화', '윌리엄', '니', '가', '만든', '영화', '다시', '보면', '내', '가', '개다']
# ['전율', '을', '느꼈다']
# ['왜', '이런', '영화', '들', '은', '재미', '가', '없는', '걸까', '요']
# ['하여간', '구', '하러', '간', '넘이', '더해요', 'ㅋㅋ']
# ['개인', '적', '으로', '잡스', '가', '롤모델', '이지만', '너무', '잡스', '의', '인생', '중', '중요한', '요점', '은', '다', '뺀것', '같네요', '처음', '부분', '에선', '기대', '를', '했지만', '후반', '부로', '갈수록', '내용', '이', '산만해지네요']
# ['도대체', '영점', '은', '왜', '없는거냐']
# ['용기', '가', '대단하다', '이런', '영화', '가', '많이', '나오기를']
# ['제목', '찾느라', 'OO', '뻔했네', '내', '비록', '나이', '쳐', '먹어', '간다', '지만', '진짜', '재밌게', '본', '기억', '이', '있다', '이', '거']
# ['소이현', '진짜', '딱', '내', '이상형', '스타일', '로', '나옴', 'ㅋㅋㅋ', '1등', '댓글', '이', '닷', 'ㅋ']
# ['아', '최고', '의', '명작', '앞', '으로', '이런', '영화', '가', '나올까', '싶어요']
# ['너무', '좋아요', '노래', '도', '좋고', '또', '보고', '싶네요']
# ['지루하지도', '않고', '신나지도', '않고']
# ['습작', '기', '의', '수준', '이다', '볼', '만', '했던', '건', '어설퍼서', '귀여웠던', '곽지민', '의', '일진', '연기', '뿐', '이다']
# ['초등학교', '때', '선생님', '이', '보여주신', '영화', '시간', '이', '흘러서', '기억나는건', '에이즈', '에', '걸렸던', '남자아이와', '운동화', '였고', '그때', '봤던', '영화', '가', '뭐', '였을까', '궁금했었는데', '그', '영화', '가', '바로', '굿바이', '마이', '프렌드', '였다', '12년', '전이나', '12년', '후나', '명작', '은', '시간', '이', '흘러도', '명작', '이다']
# ['완전', '재미없음', '점수', '도', '아까', '움']
# ['말', '이', '필요', '없는', '애니메이션']
# ['순풍', '왠', '만', '은', '비슷했으나', '여기', '서', '완전', '무너져', '버렸지', '정말', '별로', '였음']
# ['최고', '의', '영화', '였다', '군', '시절']
# ['재밌게', '봤던', '영화', '가족', '들', '의', '사랑', '을', '일', '깨워주는', '그', '저', '그런', '전개', '긴', '하지만', '이', '영화', '보고나서', '아쿠아리움', '을', '가서', '펭귄', '을', '보고', '올까', '생각', '을', '했을', '정도', '로', '펭귄', '들', '이', '너무', '귀엽다', '어린', '자녀', '가', '있다면', '가족', '끼리', '무료', '한', '주말', '낮', '에', '재밌게', '볼', '수', '있는', '가족영화']
# ['대장금', '의', '제빵', '버전', '같기도', '한데', '문제', '는', '너무', '유치하다']
# ['간만', '에', '홀릭하', '게', '된', '프로', '에요', '조여정', '씨', '랑', '박', '세현', '씨', '넘', '잘', '어울려요', '꼭', '결혼', '하셨으면', '좋겠어요', '박', '세현', '씨', '서울', '에', '오는', '이야기', '도', '다뤄주세요', 'ㅎ', '궁금해요', '진짜', '오게', '되는지', 'ㅎ']
# ['f', '이', '것', '도', '영화', '라고', 'ㅋㅋ']
# ['짠하다']
# ...
# ['드라이브', '를', '본', '후', '기대', '를', '많이', '하고', '봤지만', '실망', '만', '컸음']
# ['ㅠㅠ', '보는', '내내', '눈물', '만', '저', '남자']
# ['오늘', '있었던', '일', '얘기', '해봐', '그게', '이', '영화', '보다', '재밌다']
# ['쓰레기']
# ['봐도', '봐도', '또', '봐도', '달달', '하고', '입', '이', '보는', '내내', '귀', '에', '걸리는', '드라마', '다']
# ['얼마나', '웃었던지', 'ㅎㅎㅎ', '신선함']
# ['오늘', '똥개', '를', '보았습니다', '줄거리', '잔혀', '모르고', '봤더니', '확실히', '영화', '가', '재밌습니다', '정우성', '을', '비롯', '하여', '출연', '배우', '들', '의', '연기력', '에', '감탄', '하면', '즐겁게', '잘', '봤습니다', '한국영', '화', '점점', '대단해져서', '무척', '좋습니다']
# ['EBS', '를', '통해', '보았는데', '매우', '이', '영화', '는', '잘', '못', '되었다', '이', '영화', '는', '역사', '에', '잘', '못', '되었다']
# ['와', '더불어', '재밌게', '본', '1998년', '작의', '한국영', '화', '다']
# ['사회', '소수자', '들', '을', '되돌아보는', '계기']
# ['내', '가', '아끼는', '영화']
# ['감독', '님', 'ㅡㅡ', '아이돌', '발연기', '가지', '고', '왜', '되도', '않는', '멜로', '스토리', '에여', 'ㅡㅡ', '술', '깰라고', '빙수', '사먹고', '본', '방사', '슈햇', '는대', '이', '게머애', '여', 'ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ']
# ['다시', '보고싶은', '영화', '보는', '내내', '흥미로웠다', '별', '점', '이', '낮은건', '사람', '들', '의', '영', '화보', '는', '기준', '이', '달라', '서인', '듯']
# ['초', '특급', '액션', '만화', '를', '통쾌한', '영상', '으로', '옮긴듯', '한', '내용', '과', '연출', '이었다', '체리', '달링', '은', '이제껏', '본', '여', '전사', '중', '최고', '로', '매력', '적']
# ['고', '3', '수험생', '이', '였던', '제', '게', '참', '나쁜', '드라마', '였던']
# ['이', '거', '죠', '이', '거']
# ['그래서', '키리시', '마가', '대체', '어떻게', '생긴', '놈', '이냐']
# ['아레잇는넘', '보', '니까', '영화', '보지', '도', '않고', '그', '많은', '영화', '를', '허세', '부리고', '평점', '을', '쓰', '렉', '으로', '주내']
# ['일본', '침몰', '하면', '손', '해보는건', '한국', '도', '마찬가지', '라서', '1', '점줌']
# ['오늘', '막방', '너무', '슬펐어요', '꽃', '들', '의', '전쟁', '모든', '연기자', '분들', '수고', '많았어요', '다음', '작품', '맏', '이', '도', '기대', '되네요', '무자식', '에서', '꽃', '들', '의', '전쟁', '까지', '정말', '재미있었어요']
# ['후', '진짜', '졸작', '이다']
# ['실', '평점', '은', '7', '점', '이지만', '평점', '이', '너무', '높은', '관계', '로', '정말', '마지막', '5분', '을', '빼고는', '쓰레기', '네', '요']
# ['나', '만', '죽', '을', '순', '없다']
# ['뭔가', '그럴', '싸', '해보이지만', '완전', '짜증나는', '허', '접', '공포']
# ['초', '대박', 'ㅋㅋㅋㅋ', '아이', '는', '살아있다', 'ㅋㅋㅋㅋ']
# ['김혜선', '씨', '의', '몸매', '때문', '에', '10', '점', '젊은', '애', '들', '실리콘', '쳐', '박아', '넣은거랑', '차원', '이', '다름']
# ['이', '거', '볼바', '야', '그냥', '야동', '을', '봐라', 'ㅋㅋㅋ']
# ['에르몬넬', '라', '야호', '의', '연기력', '이', '돋보였던', '오페라', '몰입', '이', '너무', '잘', '됐어요']
# ['머', '야', '이', '새', '낀', '나라', '팔', '아', '먹으', '넘아', '녀']
# ['인상', '깊은', '결말', '만', '빼고', '나머진', '그닥', '별로', '다']
# ['재미', '더럽게', '없다', '2', '점', '부터', '점수', '준거', '매미', 'OO']
# ['일본', '에서는', '무표정', '에', '합리', '적', '이고', '기계', '같은데', '뭔가', '아픈', '사연', '있는', '여', '주인공', '이', '이끌어가는', '드라마', '를', '좋아하는듯', '근데', '올해', '만도', '이런', '리메이크', '가', '3', '번', '이다', '그', '래서', '인지', '별로', '뒷이야기', '는', '궁금하지', '않고', '한국인', '정서', '에도', '안', '맞게', '구성', '했으니', '평점', '높게', '못', '주겠다']
# ['3', '기', '가', '까지', '나온', '현재', '인간', '의', '고뇌', '와', '자아', '찾기', '범죄', '의', '지', '속성', '빠지는것', '없는', '작품']
# ['조시', '게드', '진짜', '웃김', 'ㅋㅋㅋ']
# ['이영화', '를', '보면', '모든', '남자', '가', '다', '이런', 'OO', '이', '발정', '난', 'OOO', '처럼', '보이실수있지만', '맘', '따뜻하고', '사랑', '하는', '사람', '을', '아껴주기', '위해', '자기', '자신', '을', '절제', '하는', '남자', '도', '많습니다', '영화', '보고', '꽤', '나', '기분', '이나', '빳', '네', '요', '영화', '자체', '는', '그리', '나쁜것', '같진', '않지만']
# ['적어도', '한반도', '보다는', '재미있는', '영화', 'MSG', '무', '첨가', '영화']
# ['Boy', 'next', 'door', '도', '출연', '하면', '좋습니다']
# ['이야기', '전개도', '정말', '재미있고', '배우', '들', '연기', '도', '하나같이', '모두', '뛰어난', '드라마']
# ['조금', '유치하지만', '가볍게', '볼수는', '있는', '영화', '네', '요']
# ['가족', '은', '우리', '의', '파랑새', '이고', '파랑새', '는', '희망', '을', '뜻', '하고', '프롯', '은', '그', '희망', '을', '정신', '병동', '에서', '정신', '병자', '에게', '보여준다', '관계', '의', '중요성', '과', '희망', '을', '잃지말라는', '교훈', '을', '감독', '은', '우리', '에게', '영화', '를', '통해', '보여준다', '프롯', '은', '가족', '과', '희망이', '없다면', '케이', '팩스', '로', '데리', '고', '간다']
# ['할', '말', '없음']
# ['실화', '인걸', '모르고', '본', '나', '는', '별로', '스토리', '진행', '이', '늘어지고', '겉멋', '부리는', '장면', '만', '많음']
# ['언제', '끝나냐', '하면서', '시계', '보면서', '보는', '영화', 'REC', '아', '류작', '정말', '그만', '울거', '먹으라', '똑같은', '스토리', '똑같은', '핸드', '핼드', '뱀파이어', '아', '류', '사류', '작', '영상', '은', '괜찮아', '근데', '내용', '은', '정말', '짜증난다', '차라리', '그냥', '초반', '부터', '주', '욱', '여행', '블로그', '로', '가는게', '좋았을듯', '무슨']
# ['b', '급', '감성', 'ㅋㅋㅋ', '생각', '보다', '꿀잼', 'ㅋㅋㅋㅋ']
# ['1', '점도', '아까운', '영화', 'ㅡㅡ']
# ['뭐', '여', '이', '게', 'ㅡㅡ', '코난', '보고', '만들었나']
# ['징그럽게', '느껴지는', '건', '나', '만', '그런', '게', '아닐테지']
# ['개봉', '때', '극장', '관람', '관람', '중', '퇴장', '하는', '사람', '많았음', '인생', '최악', '의', 'OOO', '애니']
# ['지겹다']
# ['내', '가', '본', '영화', '중', '에', '가장', '슬프고', '충격', '적', '이고', '비극', '적', '인', '영화', '였다', '이자벨', '아자', '니', '라는', '분', '이', '정말', '연기', '를', '잘', '해서', '몰입도', '가', '높았던것', '같다']
# ['재미', '읎', '당', '1', '점', '준것', '중', '에', '한국영', '화', '는', '죄다', '8', '10', '점준', 'M', '창', '있네']
# ['쓰레기', '뭘', '10', '자', '까지', '적으래']
# ['정말', '해도', '해도', '너무한다', '킬링', '타임', '이', '아니고', '킬링', '마인드', '인듯']
# ['너무', '어중간함', '스파이', '영화', '라기', '엔', '액션', '이', '너무', '없고', '연', '애물', '이라기', '엔', '너무', '밋밋하고', '이런', '영화', '는', '양쪽', '의', '장점', '을', '살려야', '하는데', '둘다', '망함', '그', '결과', '볼거리', '가', '없고', '지루함']
# ['쓰레기', '다', '카메라맨', '덕', '에', '오바이트', '할', '뻔했음']
# ['최근', '개봉', '된', '뮤지컬', '식', '레미제라블', '보다', '1999년', '개봉', '된', '이영화', '가', '더', '감동', '적', '이었다', '레', '미제', '라', '블']
# ['다', '만들어놓은', '밥상', '에', '투정', '부리거나', '나불', '거리', '긴', '쉽지', '그', '징', '평', '식', '씨']
# ['판타지', '공포', '기술', '은', '진보', '했어도', '예전', '만', '한', '걸작', '은', '없는듯']
# ['완전', '최고', '제', '가슴', '이', '보고', '난', '이후', '아직도', '두근거리네요']
# ['코믹', '감동', '사랑', '모든', '게', '발', '만', '담구고', '수건', '으로', '닦지도', '않은', '느낌', '아담샌들러', '의', '코믹', '을', '좋아하는', '사람', '으로써', '한없이', '부끄러운', '작품', 'ㅠ']
# ['뭐', '야', '이', '거', '할려면', '화끈하게', '하던지', '장난', '치냐']
# ['3', 'D', '를', '벗어난', '평면', '만화영화', '문화', '가', '달라', '서', '인가']
# ['진실된', '단', '한', '번의', '사랑', '부럽다']
# ['근래', '본', '것', '중', '제일', '재밌었어요']
# ['삐', '까', '뻔쩍', '한', '동기', '소재', '전혀', '어긋난', '도깨비', '시장', '영', '화판']
# ['이런', '드라마', '보면', '착하게', '살', '면', '좋은', '일이', '생긴다', '뭐', '이런', '느낌', '을', '받아요']
# ['재밋어용', 'ㅎㅎ']
# ['정말', '좋은', '영화', '라고', '생각', '해요', '1시간', '30분', '동안', '관객', '들', '의', '욕', '이란', '욕', '은', '다', '들을수', '있는', '영화', '였습니다']
# ['난', '좋았다']
# ['날가져요', '엉엉', 'ㅠ', 'ㅠ']
# ['재미있고', '다른', '느낌', '이라', '더욱', '좋았던것', '같습니다']
# ['내', '가', '옛날', '에', '1', '점', '줬다고', '배급사', '한테', '협박', '메일', '와', '서', '지우', '라고', '했더니', '결국', '망햇', '구나', 'ㅋㅋ']
# ['빠른', '스토리', '전개', '가', '좋아요', '일단', '연기력', '들', '이', '탄탄해서', '볼', '만', '했', '습', '니당']
# ['영화', '잘', '만들었네요']
# ['보는', '사람', '고려', '않고', '자기', '생각', '을', '혼자', '막', '보여', '대는', '영화']
# ['이루지', '못', '한', '사랑', '에', '아쉬움', '이', '남는다', '전쟁', '이', '낳은', '비극', '을', '나타낸다', '전쟁', '은', '역시', '결코', '없어', '야한다', 'But', '비비안리', '연기', '만점', 'and', '로버트', '테일러', '같은', '남자', '어디', '없을까']
# ['그런대로', '재미있게', '봤어요']
# ['생계', '형', '살인마']
# ['볼때', '마다', '이', '작품', '은', '잘', '만들었다고', '생각', '합니다', '보고', '보고', '또', '보고싶고']
# ['허허', '이런', '영화', '는', '보면안되']
# ['성룡', '영화', '의', '절정']
# ['아내', '돈', '감동', '적', '이', '지도', '않고', '재밋', '지도', '않음', 'ㅡㅡ']
# ['자막', '읽다', '이렇게', '지쳐', '보긴', '처음', '이네']
# ['볼땐', '몰렀는데', '다른', '코미디', '영화', '와', '비교', '해', '보면', '이보', '다', '허', '접', '할수', '없다']
# ['아', '이', '박복한', '트리스탄', 'ㅜㅜ']
# ['김예림', '목소리', '너무', '답답해']
# ['어디서', '본', '듯', '한', '상황', '과', '장면', '들', '이', '좀', '진부하게', '느껴진다']
# ['이런', '재밌는', '영화', '같으니라', '구']
# ['정말', '신도', '밉고', '인간', '도', '싫다']
# ['램페이지', '시리즈', '는', '내', '인생', '최고', '의', '영화', '들', '중', '하나', '다']
# ['심심할', '때', '보면', '의외로', '웃긴', '영화']
# ['마음속', '에', '콕콕', '콕']
# ['이쁜', '영화']
# ['긴장감', '마지막', '까지', '덜덜', '덜', '총', '들', '고', '잇어서', '무섭지만', '멋있는', '오빠', '들', '과', '함께', '해서', '좋았던', '영화']
# ['참신할', '뻔', '하다가', '역시', '나', '식상한', '뻔', '한', '영화', '배우', '가', '아깝다']
# ['이런', '걸', '미국', '까지', '가서', '찍어서', '개봉', '한', '다니', '어색한', '발연기', '에', '어색한', '한국어', '는', '뭔', '지', '최민수', '경력', '에서', '지워', '야할', '영화']
# ['이', '게', '머냐', '제', '작', '진', '은', '반성', '해라', '시즌', '원', '에', '반', '만큼만', '해도', '이런', '소리', '는', '안', '듣는다', '차라리', '일반인', '으로', '채워라']
# ['내', '가', '태어나', '본', '사람', '중', '에', '가장', '이쁘다고', '생각', '한', '사람', '이', '올리비아', '핫세', '인데', '이영화', '에서의', '소', '피', '마르', '소의', '미모', '는', '이미', '인간', '사가', '아닌듯', '싶다', '여신', '그', '자체', '인', '듯', '하', '다']
# ['옛날', '영화', '좋아요', '톰', '행크스', '맥', '라이언', '커플', '을', '새', '영화로', '볼수는', '없겠죠']
# ['빼어난', '그림', '이', '영화', '에', '가져다주는', '효과', '란', '하지만', '흡혈귀', '의', '사랑', '인데', '너무', '사실', '적', '으로', '그린건', '아쉽다', '그런', '면', '에선', '리메이크', '작', '이', '나은지', '도']
# ['내', '가', '포병', '출신', '인데', '155', 'mm', '포탄', '을', 'GPS', '유도', '미사일', '이라고', '하다니', 'ㅋㅋㅋ', '어이', '가', '없어서', '몰입', '이', '도저히', '안', '됐음', 'ㅋㅋㅋㅋㅋ', '그리고', '저', '거', '한', '발', '에', '40', 'KG', '이', '넘어서', '저렇게', '장난감', '다루', '듯이', '는', '못듬', 'ㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['영화', '에', '없는', '것', '아프리카', '역사', '과학', '고릴라']
# ['초반', '부', '에', '웃으면서', '눈물', '을', '글썽', '였다', 'ㅎㅎ', '정말', '저럴지도', '모른다는', '묘', '한', '공감', '과', '어릴', '때', '생각', '도', '나고', '산타', '에', '대한', '환상', '이', '깨진', '때', '생각', '도', '나고', '이', '영화', '는', '환상', '을', '지켜주는', '예쁜', '영화', '다']
# ['부연', '설명', '이', '필요', '없다', '인간', '이', '없는', '동물', '이', '주인', '되는', '서커스', '를', '위', '한', '위대한', '도전', '인간', '들', '반성', '하', '라']
# ['속편', '의', '비애']
# ['재미', '씀']
# ['최고', '의', '영화', '엄청난', '상상력', '과', '많은', '숨은', '뜻', '을', '품고', '있는', '영화']
# ['나', '만', '당할', '순', '없지', 'ㅋㅋㅋ']
# ['배우', '들', '봐라', '와', '조', '연애', '덜', '이지', '금', '다', '주연']
# ['마지막', '반전', '으로도', '충분히', '10', '점', '이', '가능하다', '마지막', '보고', '진짜', '충격', '먹음']
# ['아', '드럽게', '재미없네']
# ['리들리', '스콧', '이', '이렇게', '지저분한', '감독', '이었다니']
# ['정말', '시간', '가는줄', '모르고', '긴장', '하면서', '봤구나']
# ['앞', '으로', '좀', '더', '두고', '봐야겠음', '솔직히', '첫', '방', '은', '실망']
# ['성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져라', '성우', '밥그릇', '책임져']
# ['내', '인생', '최고', '의', '영화', '입니다']
# ['카지노', '영화', '라고', '기대하고', '주윤발', '이라고', '기대했는데', '카지노', '부분', '3', '번', '나오고', '주윤발', '거의', '안나', '옴', '스토리', '도', '이건', '도박', '이', '아니고', '그냥', '그냥', '그냥', '일상', '얘기', '뿐', '감독', '스탭', '배우', '들', '고생', '한', '건', '알게', '지만', '왜', '이따', '구로', '만들었지']
# ['그러하다', '창문', '은', '탈출', '구가', '아니다']
# ['제목', '만큼', '성과', '가', '없다', '전성기', '의', '존', '보이', '트', '보는', '것', '으로만', '만족']
# ['전', '괜찮던데요', '전체관람가', '라고', '나와있', '자냐요', '15', '세', '영화', '를', '보지']
# ['여자친구', '가', '저', '랑', '보지', '않앗는데', '봣다', '고', '합니다', '이', '영화', '는', '사라져', '야합니다']
# ['차인표', '는', '드라마', '보다', '유독', '영화', '선택', '에', '낮게', '평가', '받는', '이유', '가', '이런', '작은', '선택', '들', '이모', '여', '장강', '의', '대하', '를', '이루기', '때문', '이다', '차인표', '는', '정말', '영화', '시나리오', '보는', '안목', '이', '정말', '없다', '육상', '효', '의', '습작', '그래도', '방가', '방가', '라고', '가기', '위', '한', '소중한', '첫걸음', '이라고', '보면', '좀', '견딜만', '할거라고', '생각', '해']
# ['유년기', '의', '잊을수', '없는', '영화', '당신', '을', '평생', '기다렸어요']
# ['류승범', '연기', '신인', '듯', '가볍게', '잘', '봤다', 'ㅎㅎ']
# ['아직도', '가끔', '텔레비전', '에서', '해주면', '당연히', '봅니다', '저', '에게는', '최고', '의', '코미디', '영화', '재밌고', '항상', '가슴', '에', '남는', '영화', '입니다']
# ['처음', '부터', '끝', '까지', '저', '도', '같이', '고뇌', '했습니다']
# ['진짜', '지루']
# ['tv', '전', '기세', '가', '아깝다']
# ['1', '편', '에', '비하면']
# ['어제', '정말', '실망', '인종차별', '인지', 'ㅉㅉ', '오취', '리', '꼭', '성공', '하시길', '정말', '수준', '이하', '방송', '이네', '요']
# ['통일', '이', '되길', '바라는', '맘', '으로', '평점', '10']
# ['그냥', '우연히', '보게', '되었는데요', '수위', '는', '높지만', '반전', '이', '있네요', '볼', '만', '했습니다', '남자', '는', '잘생기고', '볼일', '이네', '요']
# ['되게', '재밌게', '봤다', '우디', '해', '럴슨', '의', '연기', '가', '인상', '깊다']
# ['지진희', 'ㅋㅋㅋ', '책', '읽는거냐', '뭐', '냐', '연기', '줫망', '이네', 'ㅋㅋ', '드라마', '서', '왕', '이나', '해', '라']
# ['감동', '입니다', '직접', '한번', '보세요', '데이빗', '고든', '그린', '감독', '의', '영화', '는', '늘', '깊은', '성찰', '을', '주는듯', '합니다']
# ['볼', '만', '했는데', '9', '점', '급', '은', '아님', '그냥', '5', '6', '점', '정도']
# ['진짜', '이상한', '영화', '삐리리씬', '이', '대사', '보다', '더', '길어', '망할만', '하다']
# ['배우', '들', '이', '아깝다', '감독', '연출', '공부', '좀', '더', '하셔', '야할듯']
# ['김윤석', '유해진', '이', '아깝다', '뭐', '이런', '쓰레기', '같은', '영화', '에', '출연', '했냐']
# ['주식', '이', '뭔', '지', '조금', '만', '알아도', '참', '재밌게', '볼', '수', '있는', '작품', '입니다', '숨어있는', '명작', '중', '의', '한', '작품', '더불어', '박용하', '씨', '가', '참', '그립네요']
# ['재밋겟네', '요']
# ['멈출수', '없는', '서서히', '조여오는', '공포', '가', '얼마나', '잔인한지', '대놓고', '시각', '으로', '표현', '한', '영화']
# ['토끼', '귀여워요']
# ['말', '이', '필요없어']
# ['마지막', '장면', '에서', '감동', '받음']
# ['캠', '무비', '장르', '여서', '인지', '현장', '감', '을', '보여줬다고는', '하나', '돈', '내고', '온', '관객', '들', '에게', '혼란', '만', '가중', '시키고', '그냥', '놀이', '공원', '입체', '체험', '관', '들어가서', '스릴', '감', '느끼고', '나오는', '거', '랑', '무슨', '차이', '가', '있는지', '모르겠다', '개인', '적', '으로', '최악', '의', '영화']
# ['나오지', '말았어야', '했다']
# ['중학교', '때', '벌써', '8년', '전에', '본', '영화', '인데', '아직', '까지', '여운', '이', '남아있다', '진짜', '정말로', '좋은', '영화']
# ['요가', '학원', '에', '이을', '공포', '스럽지', '않은', '영화']
# ['이연희', '땜', '에', '배렸', '네', '연기', '의', '질', '을', '떨어', '트리', '는', '애']
# ['영화', '의', '소재', '인', '무당', '을', '뺀', '모든', '장면', '은', '참', '재밌다', '아주', '재밌는', '장면', '에서도', '갑자기', '무당', '소재', '가', '끼어들면', '노', '잼', '이', '되어', '버리는데', '소재', '의', '유치함', '때문', '에', '아쉽다']
# ['강동원', '김정화', '짱']
# ['눈', '이', '괴로운', '영화']
# ['원작', '을', '안', '봤으면', '볼', '만', '했을', '까']
# ['얼음', '강', '을', '보고', '양심', '적', '병역기피', '가', '아닌', '양심적병역거부', '가', '한국', '역사', '에서', '약', '70년', '전부터', '있어', '왔었고', '적지', '않은', '사람', '이', '감내', '해왔는데', '이제', '라도', '많은이', '들에게', '알려질수있어서', '기쁨니다', 'ㅎ', '그리고', '내', '용도', '공감', '되고', '좋았고', '많으', '생각', '을', '하게', '되었습니다']
# ['왜', '도대체', '왜', '만들고', '찍은거야', 'ㅋ']
# ['레비아탄', '과', '함께', '꽤', '재미있게', '보았던', '영화']
# ['꽃', '한송이', '놓고', '갑니다', 'ㅋㅋ']
# ['한예슬', '에', '의한', '한예슬', '을', '위', '한', '영화']
# ['박미선', '은', '웁니', '다']
# ['지금', '봐도', '너무', '잘', '만든', '클레이', '애니', '이', '짧은', '시간', '에', '이', '토록', '큰', '재미', '를', '주다니']
# ['중간', '중간', '잉', '잉', '하고', '의문', '을', '갖게', '한다', '하지만', '불편하지', '않고', '그저', '궁금하다', '아', '멜', '리', '에를', '둘러싸고', '있는', '환경', '은', '어쩌면', '매우', '평범하지만', '그', '안', '에', '있는', '아', '멜', '리', '에가', '너무', '사랑스러워', '모든', '것', '을', '특별하게', '마치', '동화', '처럼', '만들어주는', '느낌', '이다', '예쁘다', '사랑스럽다']
# ['그녀', '의', '힘든', '여정', '과는', '달리', '영화', '는', '늘어진다']
# ['웃으면서', '보다가', '갈수록', '내용', '이', '명작']
# ['완전', '재밌음', '그리고', '감동', '쩔었음', 'ㅠ', '교훈', '이', '대박', '인', '듯', '그리고', '실화', '라서', '뭔가', '더', '몰입', '됬다']
# ['보고나오면서', '엄빠', '가', '생각났어요', '부모님', '께', '보여', '드리면', '좋을', '영화']
# ['내', '인생', '을', '한번', '더', '생각', '하게', '해주는', '영화', '였습니다']
# ['한국', '놈', '들', '참', 'ㅋㅋ', '수준', '이', '대단하시네', '이런', '영화', '에', '평점', '을', '8', '점', '이상', '씩', '주는건', '도대체', '세상', '찬', '단순하게', '살아서', '한편', '으론', '부럽네', 'ㅋㅋ']
# ['주식', '해보려는', '사람', '한테', '한번', '정도', '는', '보여주자']
# ['10년', '이', '지난', '지금', '도', '잊혀', '지지', '않는', '영화']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ed0f129887ff> in <module>
#      10     token = []
#      11     words = Okt().morphs(stc)
# ---> 12     print(words)
#      13     for word in words:
#      14         if word not in stopwords:
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# fit on texts는 train기준으로 한번만 한다. 
# train에 해당되지 않는 단어는 사라진다.
# 데이터가 사라지는게 싫으면 전체데이터를 stopwords한 다음 fit_on_text를 진행한다.
# 안에 값을 넣어주면 해당되는 값만큼 인덱스를 부여한다.
# 무의미하게 아무렇게 단어를 고르는게 아니라 단어 빈도수가 너무 적은 필요없는 단어를 제외하고 필요한 단어 5000개만 잡아서 넣어준다.
# 데이터를 분석하여 유의미한 데이터 갯수를 파악한 뒤어 사용해야한다. 그냥 사용하다가는 의미있는 데이터가 날라간다.

tokenizer = Tokenizer(5000) 
tokenizer.fit_on_texts(X_train)

# 동일한 단어는 동일한 인덱스
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
