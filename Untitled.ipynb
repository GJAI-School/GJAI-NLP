# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import re

# %%
movies_pd = pd.read_csv('./movie_data.csv')
movies_pd.columns = ['movie_id', 'title', 'star', 'movie_rating', 'genre', 'director', 'actors', 'summary']

movies_pd
# Out:
#     movie_id       title  star movie_rating  \
# 0      10994     19번째 남자  7.58     청소년 관람불가
# 1      10727      48시간 2  7.68     청소년 관람불가
# 2      10630      7월 4일생  9.07      15세 관람가
# 3      10926  90 벌레먹은 장미  0.00     청소년 관람불가
# 4      14478     9일간의 정사  7.00           NR
# ..       ...         ...   ...          ...
# 93     11160       마담 엠마  9.00           NR
# 94     10953         마루타  6.98           NR
# 95     11371       마르셀리노  9.90       전체 관람가
# 96     20679        마리화나  6.50     청소년 관람불가
# 97     14225          마야  0.00           NR
#
#                                 genre  director  \
# 0            ['코미디', '드라마', '멜로/로맨스']      론 쉘톤
# 1   ['범죄', '액션', '드라마', '코미디', '스릴러']      월터 힐
# 2                       ['전쟁', '드라마']    올리버 스톤
# 3                             ['드라마']       노세한
# 4                            ['이탈리아']   브루노 마테이
# ..                                ...       ...
# 93         ['액션', '드라마', '범죄', '스릴러']    사무엘 풀러
# 94                             ['공포']       모돈불
# 95                     ['코미디', '드라마']  라디슬라오 바다
# 96                             ['한국']       김인수
# 97                           ['이탈리아']
#
#                             actors  \
# 0   ['케빈 코스트너', '수잔 서랜든', '팀 로빈스']
# 1                ['에디 머피', '닉 놀테']
# 2                        ['톰 크루즈']
# 3                   ['남성훈', '김희아']
# 4                               []
# ..                             ...
# 93          ['키스 캐러딘', '발렌티나 바거스']
# 94                          ['왕강']
# 95         ['파블리토 칼보', '라파엘 리벨레스']
# 96           ['김경진', '박준규', '성미진']
# 97  ['윌리엄 버거', '미렐라 단젤로', '피터 펄스']
#
#                                               summary
# 0   마이너 리그팀 중의 하나로 캐롤라이나 리그에서 허덕이던 더럼 불즈팀이 오랫동안 기대...
# 1   형사 잭(Jack Cates: 닉 놀테 분)은 범죄단 두목 아이스맨을 추적하다 번번...
# 2   건실한 청년 론(Ron Kovic: 톰 크루즈 분)은 고교시절 레슬링 선수로 땀 흘...
# 3   대학시절 남자에게 배신당한 정희는 30세가 되도록 남자들의 사랑을 불신하며 독신으로...
# 4   미국인 피아니스트 제시카는 콘테스트에 참가하기 위해 베니스에 온다. 그러나 도착해서...
# ..                                                ...
# 93  인기 절정의 록큰롤 가수 마이클은 그와 특별한 사이인 매니저 로다의 주선으로 신작 ...
# 94  1945년 모든 전선에서 일본군이 패하고 있을 무렵 뇌물수수로 예편 당한 의학박사 ...
# 95  천진한 5세의 소년 마르셀리노를 통해 예수 환생의 기적을 묘사하고 있다. 1955년...
# 96  비 정상적이고 히로뽕에 중독된 만포 일당, 사회나 가정으로부터 비정상적인 정을 느끼...
# 97  평생 빛과 암흑의 세계로 가는 유일한 길을 찾던 솔로몬이 죽던 날밤, 자발바이의 피...
#
# [98 rows x 8 columns]
